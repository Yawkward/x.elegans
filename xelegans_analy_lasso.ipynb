# %%
# use kernel py3-6
#import goatools
from goatools import obo_parser
import re
import json
import numpy as np
from goatools.go_enrichment import GOEnrichmentStudy
import matplotlib.pyplot as plt

# %% [markdown]
# # Function to match non-zero Features in GFF and Map GO-Term to GO-ID using GOATools

# %%
def matchgff2(feature, gff_file='/home/t44p/PW_rawdata/Transciptome_GenomeAnnotation/Xele_annotated2_gff_export2.gff', obo_path="/home/t44p/PW_rawdata/go_obo/go.obo", namespace=None, depth_threshold=0, goea=False):
    """
    Searches a GFF (General Feature Format) file for specific features and retrieves associated Gene Ontology (GO) terms.

    Parameters:
    ----------
    feature : list or iterable
        An iterable of strings representing the features to search for in the GFF file.

    gff_file : str, optional
        The file path to the GFF file. Defaults to '/home/t44p/PW_rawdata/Transciptome_GenomeAnnotation/Xele_annotated2_gff_export2.gff'.

    obo_path : str, optional
        The file path to the Gene Ontology .obo file. Defaults to "/home/t44p/PW_rawdata/go_obo/combined.obo".

    Returns:
    -------
    tuple of dict
        A tuple containing two dictionaries:
        1. A dictionary where keys are the features and values are lists of lines (as strings) from the GFF file where these features are found.
        2. A dictionary where keys are the features and values are dictionaries. Each inner dictionary has GO IDs as keys and a dictionary with 'name' and 'namespace' of the GO term as values.

    Example:
    --------
    #>>> features = ['gene1', 'gene2']
    #>>> matchgff2(features)
    ({'gene1': ['line content from GFF file'], 'gene2': ['line content from GFF file']},
     {'gene1': {'GO:0000001': {'name': 'term name', 'namespace': 'biological_process'}}, ... })

    Notes:
    -----
    The function uses regular expressions for precise matching of features. It expects the feature followed by a tab character in the GFF file.
    Additionally, it extracts GO IDs from matched lines and retrieves their corresponding names and namespaces from the provided Gene Ontology .obo file.
    """

    valid_namespaces = {'biological_process', 'molecular_function', 'cellular_component', None}
    # Check if namespace is a list containing only valid elements
    if isinstance(namespace, list) and not all(ns in valid_namespaces for ns in namespace):
        raise ValueError("Invalid namespace provided. Valid options are 'biological_process', "
                         "'molecular_function', 'cellular_component', or a list containing any of these. "
                         "You can also use None for no filtering.")

    with open(gff_file, 'r') as file:
        go_ontology = obo_parser.GODag(obo_path)
        
        lines_where_feat_found = {}
        go_ids = {}
        background_genes = []
        go_term_count = {}

         # Find the depth of each GO term
        go_depths = {go_id: go_term.depth for go_id, go_term in go_ontology.items()}


        for feat in feature:
            file.seek(0)  # reset file pointer to the beginning for each feature
            lines_where_feat_found[feat] = []
            go_ids[feat] = {}
            pattern = re.compile(re.escape(feat) + r'\t')  # exact match followed by a tab
            for line in file:
                if goea:
                    if not line.lstrip().startswith('#'):
                        background_genes.append(line.split('\t')[0])

                if pattern.search(line):
                    lines_where_feat_found[feat].append(line.strip())  # Store the line (as a string) if feature is found
                    # Extract GO id
                    match = re.search(r"Ontology_id=([GO:\d,]+)", line.strip())
                    if match:
                        ids = match.group(1).split(',')
                        # Map Terms to Ids and Count Occurrences
                        for id in ids:
                            term = go_ontology.get(id)
                            if term is not None:
                                go_ids[feat][id] = {'name': term.name, 'namespace': term.namespace}

                                if namespace is None or term.namespace in namespace and go_ontology[id].depth >= depth_threshold:
                                    # Count Occurrences
                                    if id in go_term_count:
                                        go_term_count[id] = (term.name, go_term_count[id][1] + 1, term.namespace)
                                    else:
                                        go_term_count[id] = (term.name, 1, term.namespace)
                            else:
                                go_ids[feat][id] = {'name': None, 'namespace': None}
                                if id not in go_term_count:
                                    go_term_count[id] = (None, 1)
        if goea:
            print("GO Enrichment Analysis >>")
            goea_obj = GOEnrichmentStudy(
                background_genes,
                go_ids,  # This needs to be a dict mapping gene IDs to a set of GO IDs
                go_ontology,
                propagate_counts=False,
                alpha=0.05,  # significance level for the statistical test
                methods=['fdr_bh']  # correction method for multiple testing
            )
            goea_result = goea_obj.run_study(go_ids.keys())
            return lines_where_feat_found, go_ids, go_term_count, goea_result


        return lines_where_feat_found, go_ids, go_term_count

# %%
def plot_go_terms(term_count_dict, top_n=3, figsize=(25, 15), title="GO Term Occurrences"):
    print("THIS FUNCTION IS DEPRECATED; DO NOT USE IT")
    """
    Plots a bar chart of GO term occurrences.

    Parameters:
    term_count_dict (dict): Dictionary of GO terms with their counts.
    top_n (int): Number of top features to highlight.
    figsize (tuple): Figure size for the plot.
    title (str): Title of the plot.
    """
    # Extract terms and counts
    go_terms = list(term_count_dict.keys())
    counts = [term_count_dict[term][1] for term in go_terms]

    # Sort the terms by count and identify top features
    sorted_terms = sorted(term_count_dict.items(), key=lambda x: x[1][1], reverse=True)
    top_terms = sorted_terms[:top_n]

    # Create lists for the plot
    terms_to_plot = [term for term, _ in sorted_terms]
    counts_to_plot = [count for _, (_, count) in sorted_terms]

    # Colors - highlight top features in red, others in blue
    colors = ['red' if term in [t[0] for t in top_terms] else 'blue' for term in terms_to_plot]

    # Create the bar plot
    plt.figure(figsize=figsize)
    plt.bar(terms_to_plot, counts_to_plot, color=colors)
    plt.xlabel('GO Terms')
    plt.ylabel('Counts')
    plt.xticks(rotation=90)
    plt.title(title)
    plt.tight_layout()

    plt.show()
    print(f"top {top_n} most abundant GO Terms")
    for t in top_terms:
        print(t)

# Example usage:

# %%
"""def tabulate(term_count_dict, sort=True):
    if sort:
        print(f"count\tGO ID\tGO Term\tnamespace")
        term_count_dict = sorted(term_count_dict.items(), key=lambda x: x[1][1], reverse=True)
        for goid, values in term_count_dict:
            count, term, namespace = values
            print(f"{count}\t{goid}\t{term}\t{namespace}")
    else:
        print(f"count\tGO ID\tGO Term\tnamespace")
        for goid in term_count_dict.keys():
            if term_count_dict[goid][0] is not None:
                print(f"{term_count_dict[goid][1]}\t{goid}\t{term_count_dict[goid][0]}\t{term_count_dict[goid][2]}")
            else:
                print(f"{term_count_dict[goid][1]}\t{goid}")"""
def tabulate(term_count_dict, sort=True):
    print(f"count\tGO ID\tGO Term\tnamespace")

    # Conditionally sort the dictionary if required
    items = sorted(term_count_dict.items(), key=lambda x: x[1][1], reverse=True) if sort else term_count_dict.items()

    for goid, values in items:
        count = values[1]
        term = values[0] if values[0] is not None else "N/A"
        namespace = values[2] if len(values) > 2 else "N/A"

        print(f"{count}\t{goid}\t{term}\t{namespace}")
    #return

# %% [markdown]
# ### Glucose

# %%
with open("./lasso_models/10xKfold_lasso_output/glucose_nXcv.json", 'r') as file:
    glucose_nXcv = json.load(file)
#glucose_nXcv_matched, glucose_goids, glucose_term_count, glucose_goea = matchgff2(glucose_nXcv['common_features'], goea=True)
glucose_nXcv_matched, gluc_goids_biop, gluc_term_count_biop, gluc_goea_biop = matchgff2(glucose_nXcv['common_features'], namespace=['biological_process'], depth_threshold=2, goea=True)
glucose_nXcv_matched, gluc_goids_biop, gluc_term_count_molf, gluc_goea_molf = matchgff2(glucose_nXcv['common_features'], namespace=['molecular_function'], depth_threshold=2, goea=True)
glucose_nXcv_matched, gluc_goids_biop, gluc_term_count_cellc, gluc_goea_cellc = matchgff2(glucose_nXcv['common_features'], namespace=['cellular_component'], depth_threshold=2, goea=True)
# Out:
# /home/t44p/PW_rawdata/go_obo/go.obo: fmt(1.2) rel(2023-11-15) 46,228 Terms
# GO Enrichment Analysis >>
#
# Load  Ontology Enrichment Analysis ...
#   0%    676 of 793,572 population items found in association
#
# Runing  Ontology Analysis: current study set of 26 IDs.
# 100%     26 of     26 study items found in association
# 100%     26 of     26 study items found in population(793572)
# Calculating 236 uncorrected p-values using fisher_scipy_stats
#      236 terms are associated with     20 of 793,572 population items
#      236 terms are associated with     20 of     26 study items
#   METHOD fdr_bh:
#      236 GO terms found significant (< 0.05=alpha) (236 enriched +   0 purified): statsmodels fdr_bh
#       20 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
# /home/t44p/PW_rawdata/go_obo/go.obo: fmt(1.2) rel(2023-11-15) 46,228 Terms
# GO Enrichment Analysis >>
#
# Load  Ontology Enrichment Analysis ...
#   0%    676 of 793,572 population items found in association
#
# Runing  Ontology Analysis: current study set of 26 IDs.
# 100%     26 of     26 study items found in association
# 100%     26 of     26 study items found in population(793572)
# Calculating 236 uncorrected p-values using fisher_scipy_stats
#      236 terms are associated with     20 of 793,572 population items
#      236 terms are associated with     20 of     26 study items
#   METHOD fdr_bh:
#      236 GO terms found significant (< 0.05=alpha) (236 enriched +   0 purified): statsmodels fdr_bh
#       20 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
# /home/t44p/PW_rawdata/go_obo/go.obo: fmt(1.2) rel(2023-11-15) 46,228 Terms
# GO Enrichment Analysis >>
#
# Load  Ontology Enrichment Analysis ...
#   0%    676 of 793,572 population items found in association
#
# Runing  Ontology Analysis: current study set of 26 IDs.
# 100%     26 of     26 study items found in association
# 100%     26 of     26 study items found in population(793572)
# Calculating 236 uncorrected p-values using fisher_scipy_stats
#      236 terms are associated with     20 of 793,572 population items
#      236 terms are associated with     20 of     26 study items
#   METHOD fdr_bh:
#      236 GO terms found significant (< 0.05=alpha) (236 enriched +   0 purified): statsmodels fdr_bh
#       20 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)

# %%
print("# <<< GLUCOSE >>>")
print(f"# 10x3FoldCV mean score: {np.mean(glucose_nXcv['mean_scores'])} \n# count common features: {len(glucose_nXcv['common_features'])}")
tabulate(gluc_term_count_biop)
print("# <<< GLUCOSE >>>")
print(f"# 10x3FoldCV mean score: {np.mean(glucose_nXcv['mean_scores'])} \n# count common features: {len(glucose_nXcv['common_features'])}")
tabulate(gluc_term_count_molf)
print("# <<< GLUCOSE >>>")
print(f"# 10x3FoldCV mean score: {np.mean(glucose_nXcv['mean_scores'])} \n# count common features: {len(glucose_nXcv['common_features'])}")
tabulate(gluc_term_count_cellc)
# Out:
# # <<< GLUCOSE >>>
# # 10x3FoldCV mean score: 0.37766355282118325
# # count common features: 26
# count	GO ID	GO Term	namespace
# 2	GO:0005975	carbohydrate metabolic process	biological_process
# 2	GO:0051240	positive regulation of multicellular organismal process	biological_process
# 2	GO:0048766	root hair initiation	biological_process
# 2	GO:0055062	phosphate ion homeostasis	biological_process
# 1	GO:0006048	UDP-N-acetylglucosamine biosynthetic process	biological_process
# 1	GO:0006281	DNA repair	biological_process
# 1	GO:0006487	protein N-linked glycosylation	biological_process
# 1	GO:0006493	protein O-linked glycosylation	biological_process
# 1	GO:0007283	spermatogenesis	biological_process
# 1	GO:0019255	glucose 1-phosphate metabolic process	biological_process
# 1	GO:0030097	hemopoiesis	biological_process
# 1	GO:0034221	fungal-type cell wall chitin biosynthetic process	biological_process
# 1	GO:0006869	lipid transport	biological_process
# 1	GO:0006897	endocytosis	biological_process
# 1	GO:0009306	protein secretion	biological_process
# 1	GO:0016043	cellular component organization	biological_process
# 1	GO:1903530	regulation of secretion by cell	biological_process
# 1	GO:0005992	trehalose biosynthetic process	biological_process
# 1	GO:0005993	trehalose catabolic process	biological_process
# 1	GO:0009793	embryo development ending in seed dormancy	biological_process
# 1	GO:0009832	plant-type cell wall biogenesis	biological_process
# 1	GO:0010182	sugar mediated signaling pathway	biological_process
# 1	GO:0030437	ascospore formation	biological_process
# 1	GO:0034605	cellular response to heat	biological_process
# 1	GO:0036168	filamentous growth of a population of unicellular organisms in response to heat	biological_process
# 1	GO:0036180	filamentous growth of a population of unicellular organisms in response to biotic stimulus	biological_process
# 1	GO:0048364	root development	biological_process
# 1	GO:0048574	long-day photoperiodism, flowering	biological_process
# 1	GO:0051301	cell division	biological_process
# 1	GO:0070301	cellular response to hydrogen peroxide	biological_process
# 1	GO:0070413	trehalose metabolism in response to stress	biological_process
# 1	GO:0080186	developmental vegetative growth	biological_process
# 1	GO:2000070	regulation of response to water deprivation	biological_process
# 1	GO:1901990	regulation of mitotic cell cycle phase transition	biological_process
# 1	GO:0008286	insulin receptor signaling pathway	biological_process
# 1	GO:0045597	positive regulation of cell differentiation	biological_process
# 1	GO:0045944	positive regulation of transcription by RNA polymerase II	biological_process
# 1	GO:0006337	nucleosome disassembly	biological_process
# 1	GO:0042127	regulation of cell population proliferation	biological_process
# 1	GO:0009887	animal organ morphogenesis	biological_process
# 1	GO:0000122	negative regulation of transcription by RNA polymerase II	biological_process
# 1	GO:2000781	positive regulation of double-strand break repair	biological_process
# 1	GO:0032435	negative regulation of proteasomal ubiquitin-dependent protein catabolic process	biological_process
# 1	GO:0046658	N/A	N/A
# 1	GO:0009617	response to bacterium	biological_process
# 1	GO:0009627	systemic acquired resistance	biological_process
# 1	GO:0009737	response to abscisic acid	biological_process
# 1	GO:0009845	seed germination	biological_process
# 1	GO:0009932	cell tip growth	biological_process
# 1	GO:0010067	procambium histogenesis	biological_process
# 1	GO:0010305	leaf vascular tissue pattern formation	biological_process
# 1	GO:0010588	cotyledon vascular tissue pattern formation	biological_process
# 1	GO:0016050	vesicle organization	biological_process
# 1	GO:0032957	inositol trisphosphate metabolic process	biological_process
# 1	GO:0043933	protein-containing complex organization	biological_process
# 1	GO:0046855	N/A	N/A
# 1	GO:0046856	phosphatidylinositol dephosphorylation	biological_process
# 1	GO:0048016	N/A	N/A
# 1	GO:0048488	synaptic vesicle endocytosis	biological_process
# 1	GO:0048522	positive regulation of cellular process	biological_process
# 1	GO:0065008	regulation of biological quality	biological_process
# 1	GO:0071472	cellular response to salt stress	biological_process
# 1	GO:0071702	organic substance transport	biological_process
# 1	GO:0071705	nitrogen compound transport	biological_process
# 1	GO:2000369	regulation of clathrin-dependent endocytosis	biological_process
# 1	GO:2000377	regulation of reactive oxygen species metabolic process	biological_process
# 1	GO:0009057	macromolecule catabolic process	biological_process
# 1	GO:0007623	circadian rhythm	biological_process
# 1	GO:0009638	phototropism	biological_process
# 1	GO:0009734	auxin-activated signaling pathway	biological_process
# 1	GO:0009860	pollen tube growth	biological_process
# 1	GO:0009908	flower development	biological_process
# 1	GO:0009958	positive gravitropism	biological_process
# 1	GO:0010362	negative regulation of anion channel activity by blue light	biological_process
# 1	GO:0010540	basipetal auxin transport	biological_process
# 1	GO:0040008	regulation of growth	biological_process
# 1	GO:0046777	protein autophosphorylation	biological_process
# 1	GO:0048767	root hair elongation	biological_process
# 1	GO:0048825	cotyledon development	biological_process
# 1	GO:0062075	pollen aperture formation	biological_process
# 1	GO:2000114	regulation of establishment of cell polarity	biological_process
# 1	GO:0010584	pollen exine formation	biological_process
# 1	GO:0010930	negative regulation of auxin mediated signaling pathway	biological_process
# 1	GO:0015757	galactose transmembrane transport	biological_process
# 1	GO:0051260	protein homooligomerization	biological_process
# 1	GO:0052543	callose deposition in cell wall	biological_process
# 1	GO:0060918	auxin transport	biological_process
# 1	GO:0008643	carbohydrate transport	biological_process
# 1	GO:0015714	phosphoenolpyruvate transport	biological_process
# 1	GO:0015783	GDP-fucose transmembrane transport	biological_process
# 1	GO:0015786	UDP-glucose transmembrane transport	biological_process
# 1	GO:0048359	mucilage metabolic process involved in seed coat development	biological_process
# 1	GO:0072334	UDP-galactose transmembrane transport	biological_process
# 1	GO:0080040	positive regulation of cellular response to phosphate starvation	biological_process
# 1	GO:0070417	cellular response to cold	biological_process
# 1	GO:0006094	gluconeogenesis	biological_process
# 1	GO:0006096	glycolytic process	biological_process
# 1	GO:0009408	response to heat	biological_process
# 1	GO:0009416	response to light stimulus	biological_process
# 1	GO:0010154	fruit development	biological_process
# 1	GO:0034059	response to anoxia	biological_process
# 1	GO:0045893	positive regulation of DNA-templated transcription	biological_process
# 1	GO:0046686	response to cadmium ion	biological_process
# 1	GO:0016036	cellular response to phosphate starvation	biological_process
# 1	GO:0016311	dephosphorylation	biological_process
# 1	GO:0050829	defense response to Gram-negative bacterium	biological_process
# 1	GO:0050832	defense response to fungus	biological_process
# 1	GO:0051174	regulation of phosphorus metabolic process	biological_process
# 1	GO:0009620	response to fungus	biological_process
# 1	GO:0002088	lens development in camera-type eye	biological_process
# 1	GO:0006749	glutathione metabolic process	biological_process
# 1	GO:0006909	phagocytosis	biological_process
# 1	GO:0007040	lysosome organization	biological_process
# 1	GO:0007420	brain development	biological_process
# 1	GO:0007616	long-term memory	biological_process
# 1	GO:0007625	grooming behavior	biological_process
# 1	GO:0007628	adult walking behavior	biological_process
# 1	GO:0008542	visual learning	biological_process
# 1	GO:0015811	L-cystine transport	biological_process
# 1	GO:0031326	regulation of cellular biosynthetic process	biological_process
# 1	GO:0046034	ATP metabolic process	biological_process
# 1	GO:0055085	transmembrane transport	biological_process
# 1	GO:1903427	negative regulation of reactive oxygen species biosynthetic process	biological_process
# 1	GO:1904263	positive regulation of TORC1 signaling	biological_process
# 1	GO:0031305	N/A	N/A
# 1	GO:0006979	response to oxidative stress	biological_process
# 1	GO:0007615	anesthesia-resistant memory	biological_process
# 1	GO:0008016	regulation of heart contraction	biological_process
# 1	GO:0019722	calcium-mediated signaling	biological_process
# 1	GO:0032024	positive regulation of insulin secretion	biological_process
# 1	GO:0036444	calcium import into the mitochondrion	biological_process
# 1	GO:0042593	glucose homeostasis	biological_process
# 1	GO:0043009	chordate embryonic development	biological_process
# 1	GO:0051259	protein complex oligomerization	biological_process
# 1	GO:0051561	positive regulation of mitochondrial calcium ion concentration	biological_process
# 1	GO:0060027	convergent extension involved in gastrulation	biological_process
# 1	GO:0070509	calcium ion import	biological_process
# 1	GO:0090023	positive regulation of neutrophil chemotaxis	biological_process
# 1	GO:0090141	positive regulation of mitochondrial fission	biological_process
# 1	GO:0090527	N/A	N/A
# 1	GO:0001666	response to hypoxia	biological_process
# 1	GO:0002239	response to oomycetes	biological_process
# 1	GO:0009741	response to brassinosteroid	biological_process
# # <<< GLUCOSE >>>
# # 10x3FoldCV mean score: 0.37766355282118325
# # count common features: 26
# count	GO ID	GO Term	namespace
# 7	GO:0005515	protein binding	molecular_function
# 1	GO:0000287	magnesium ion binding	molecular_function
# 1	GO:0004610	phosphoacetylglucosamine mutase activity	molecular_function
# 1	GO:0004614	phosphoglucomutase activity	molecular_function
# 1	GO:0005543	phospholipid binding	molecular_function
# 1	GO:0046872	metal ion binding	molecular_function
# 1	GO:0003825	alpha,alpha-trehalose-phosphate synthase (UDP-forming) activity	molecular_function
# 1	GO:0004805	trehalose-phosphatase activity	molecular_function
# 1	GO:0102986	trehalose synthase activity	molecular_function
# 1	GO:0003682	chromatin binding	molecular_function
# 1	GO:0046658	N/A	N/A
# 1	GO:0008810	cellulase activity	molecular_function
# 1	GO:0042973	glucan endo-1,3-beta-D-glucosidase activity	molecular_function
# 1	GO:0004439	phosphatidylinositol-4,5-bisphosphate 5-phosphatase activity	molecular_function
# 1	GO:0004445	inositol-polyphosphate 5-phosphatase activity	molecular_function
# 1	GO:0034485	phosphatidylinositol-3,4,5-trisphosphate 5-phosphatase activity	molecular_function
# 1	GO:0046855	N/A	N/A
# 1	GO:0048016	N/A	N/A
# 1	GO:0004806	triglyceride lipase activity	molecular_function
# 1	GO:0033878	hormone-sensitive lipase activity	molecular_function
# 1	GO:0047372	acylglycerol lipase activity	molecular_function
# 1	GO:0004674	protein serine/threonine kinase activity	molecular_function
# 1	GO:0004712	protein serine/threonine/tyrosine kinase activity	molecular_function
# 1	GO:0005524	ATP binding	molecular_function
# 1	GO:0005546	phosphatidylinositol-4,5-bisphosphate binding	molecular_function
# 1	GO:0005547	phosphatidylinositol-3,4,5-trisphosphate binding	molecular_function
# 1	GO:0009882	blue light photoreceptor activity	molecular_function
# 1	GO:0010314	phosphatidylinositol-5-phosphate binding	molecular_function
# 1	GO:0019901	protein kinase binding	molecular_function
# 1	GO:0032266	phosphatidylinositol-3-phosphate binding	molecular_function
# 1	GO:0070273	phosphatidylinositol-4-phosphate binding	molecular_function
# 1	GO:0070300	phosphatidic acid binding	molecular_function
# 1	GO:0080025	phosphatidylinositol-3,5-bisphosphate binding	molecular_function
# 1	GO:0106310	protein serine kinase activity	molecular_function
# 1	GO:0008080	N-acetyltransferase activity	molecular_function
# 1	GO:0051119	sugar transmembrane transporter activity	molecular_function
# 1	GO:0005457	GDP-fucose transmembrane transporter activity	molecular_function
# 1	GO:0005459	UDP-galactose transmembrane transporter activity	molecular_function
# 1	GO:0005460	UDP-glucose transmembrane transporter activity	molecular_function
# 1	GO:0015315	organophosphate:inorganic phosphate antiporter activity	molecular_function
# 1	GO:0071917	triose-phosphate transmembrane transporter activity	molecular_function
# 1	GO:0003677	DNA binding	molecular_function
# 1	GO:0004365	glyceraldehyde-3-phosphate dehydrogenase (NAD+) (phosphorylating) activity	molecular_function
# 1	GO:0042301	phosphate ion binding	molecular_function
# 1	GO:0050661	NADP binding	molecular_function
# 1	GO:0070403	NAD+ binding	molecular_function
# 1	GO:0003729	mRNA binding	molecular_function
# 1	GO:0003993	acid phosphatase activity	molecular_function
# 1	GO:0004721	phosphoprotein phosphatase activity	molecular_function
# 1	GO:0008199	ferric iron binding	molecular_function
# 1	GO:0008270	zinc ion binding	molecular_function
# 1	GO:0030145	manganese ion binding	molecular_function
# 1	GO:0003723	RNA binding	molecular_function
# 1	GO:0015184	L-cystine transmembrane transporter activity	molecular_function
# 1	GO:0015295	solute:proton symporter activity	molecular_function
# 1	GO:0034639	L-amino acid efflux transmembrane transporter activity	molecular_function
# 1	GO:0031305	N/A	N/A
# 1	GO:0005262	calcium channel activity	molecular_function
# 1	GO:0015292	uniporter activity	molecular_function
# 1	GO:0019855	calcium channel inhibitor activity	molecular_function
# 1	GO:0042802	identical protein binding	molecular_function
# 1	GO:0090527	N/A	N/A
# # <<< GLUCOSE >>>
# # 10x3FoldCV mean score: 0.37766355282118325
# # count common features: 26
# count	GO ID	GO Term	namespace
# 5	GO:0005634	nucleus	cellular_component
# 3	GO:0005737	cytoplasm	cellular_component
# 3	GO:0005886	plasma membrane	cellular_component
# 3	GO:0016021	membrane	cellular_component
# 3	GO:0005576	extracellular region	cellular_component
# 3	GO:0005794	Golgi apparatus	cellular_component
# 2	GO:0045202	synapse	cellular_component
# 2	GO:0005773	vacuole	cellular_component
# 2	GO:0005654	nucleoplasm	cellular_component
# 2	GO:0005829	cytosol	cellular_component
# 1	GO:0000139	Golgi membrane	cellular_component
# 1	GO:0010008	endosome membrane	cellular_component
# 1	GO:0098827	endoplasmic reticulum subcompartment	cellular_component
# 1	GO:0005946	alpha,alpha-trehalose-phosphate synthase complex (UDP-forming)	cellular_component
# 1	GO:0016514	SWI/SNF complex	cellular_component
# 1	GO:0001741	XY body	cellular_component
# 1	GO:0071564	npBAF complex	cellular_component
# 1	GO:0071565	nBAF complex	cellular_component
# 1	GO:0043231	intracellular membrane-bounded organelle	cellular_component
# 1	GO:0046658	N/A	N/A
# 1	GO:0009507	chloroplast	cellular_component
# 1	GO:0005768	endosome	cellular_component
# 1	GO:0005856	cytoskeleton	cellular_component
# 1	GO:0043005	neuron projection	cellular_component
# 1	GO:0046855	N/A	N/A
# 1	GO:0048016	N/A	N/A
# 1	GO:0005747	mitochondrial respiratory chain complex I	cellular_component
# 1	GO:0005811	lipid droplet	cellular_component
# 1	GO:0090406	pollen tube	cellular_component
# 1	GO:0009925	basal plasma membrane	cellular_component
# 1	GO:0009986	cell surface	cellular_component
# 1	GO:0005789	endoplasmic reticulum membrane	cellular_component
# 1	GO:0005887	plasma membrane	cellular_component
# 1	GO:0005783	endoplasmic reticulum	cellular_component
# 1	GO:0016020	membrane	cellular_component
# 1	GO:0005740	mitochondrial envelope	cellular_component
# 1	GO:0005615	extracellular space	cellular_component
# 1	GO:0005765	lysosomal membrane	cellular_component
# 1	GO:0005770	late endosome	cellular_component
# 1	GO:0042470	melanosome	cellular_component
# 1	GO:0009941	chloroplast envelope	cellular_component
# 1	GO:0031305	N/A	N/A
# 1	GO:1990246	uniplex complex	cellular_component
# 1	GO:0090527	N/A	N/A
# 1	GO:0009505	plant-type cell wall	cellular_component

# %%
# plot_go_terms(gluc_term_count_biop, top_n=10)

# %%
"""PRINT EACH GFF ENTRY AND GO-TERMS CORRESPONDING TO NO-ZERO FEATURES"""
#for ele in glucose_nXcv_matched:
#    print(f"{glucose_nXcv_matched[ele]}")
#    #print(glucose_goids[ele], "\n")
#    for id in glucose_goids[ele]:
#        print(id, ": ", glucose_goids[ele][id])
# Out:
# 'PRINT EACH GFF ENTRY AND GO-TERMS CORRESPONDING TO NO-ZERO FEATURES'

# %% [markdown]
# ### Sucrose

# %%
with open("./lasso_models/10xKfold_lasso_output/sucrose_nXcv.json", 'r') as file:
    sucrose_nXcv = json.load(file)
#sucrose_nXcv_matched, sucrose_goids, sucrose_term_count,sucrose_goea = matchgff2(sucrose_nXcv['common_features'], goea=True)
sucrose_nXcv_matched, suc_goids_biop, suc_term_count_biop, suc_goea_biop = matchgff2(sucrose_nXcv['common_features'], namespace=['biological_process'], depth_threshold=2, goea=True)
sucrose_nXcv_matched, suc_goids_molf, suc_term_count_molf, suc_goea_molf = matchgff2(sucrose_nXcv['common_features'], namespace=['molecular_function'], depth_threshold=2, goea=True)
sucrose_nXcv_matched, suc_goids_cellc, suc_term_count_cellc, suc_goea_cellc = matchgff2(sucrose_nXcv['common_features'], namespace=['cellular_component'], depth_threshold=2, goea=True)
# Out:
# /home/t44p/PW_rawdata/go_obo/go.obo: fmt(1.2) rel(2023-11-15) 46,228 Terms
# GO Enrichment Analysis >>
#
# Load  Ontology Enrichment Analysis ...
#   0%     64 of 244,176 population items found in association
#
# Runing  Ontology Analysis: current study set of 8 IDs.
# 100%      8 of      8 study items found in association
# 100%      8 of      8 study items found in population(244176)
# Calculating 70 uncorrected p-values using fisher_scipy_stats
#       70 terms are associated with      7 of 244,176 population items
#       70 terms are associated with      7 of      8 study items
#   METHOD fdr_bh:
#       70 GO terms found significant (< 0.05=alpha) ( 70 enriched +   0 purified): statsmodels fdr_bh
#        7 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
# /home/t44p/PW_rawdata/go_obo/go.obo: fmt(1.2) rel(2023-11-15) 46,228 Terms
# GO Enrichment Analysis >>
#
# Load  Ontology Enrichment Analysis ...
#   0%     64 of 244,176 population items found in association
#
# Runing  Ontology Analysis: current study set of 8 IDs.
# 100%      8 of      8 study items found in association
# 100%      8 of      8 study items found in population(244176)
# Calculating 70 uncorrected p-values using fisher_scipy_stats
#       70 terms are associated with      7 of 244,176 population items
#       70 terms are associated with      7 of      8 study items
#   METHOD fdr_bh:
#       70 GO terms found significant (< 0.05=alpha) ( 70 enriched +   0 purified): statsmodels fdr_bh
#        7 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
# /home/t44p/PW_rawdata/go_obo/go.obo: fmt(1.2) rel(2023-11-15) 46,228 Terms
# GO Enrichment Analysis >>
#
# Load  Ontology Enrichment Analysis ...
#   0%     64 of 244,176 population items found in association
#
# Runing  Ontology Analysis: current study set of 8 IDs.
# 100%      8 of      8 study items found in association
# 100%      8 of      8 study items found in population(244176)
# Calculating 70 uncorrected p-values using fisher_scipy_stats
#       70 terms are associated with      7 of 244,176 population items
#       70 terms are associated with      7 of      8 study items
#   METHOD fdr_bh:
#       70 GO terms found significant (< 0.05=alpha) ( 70 enriched +   0 purified): statsmodels fdr_bh
#        7 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)

# %%
#plot_go_terms(sucrose_term_count, top_n=10)
print("# <<< SUCROSE >>>")
print(f"# 10x3FoldCV mean score: {np.mean(sucrose_nXcv['mean_scores'])} \n# count common features: {len(sucrose_nXcv['common_features'])}")
tabulate(suc_term_count_biop)
print("# <<< SUCROSE >>>")
print(f"# 10x3FoldCV mean score: {np.mean(sucrose_nXcv['mean_scores'])} \n# count common features: {len(sucrose_nXcv['common_features'])}")
tabulate(suc_term_count_molf)
print("# <<< SUCROSE >>>")
print(f"# 10x3FoldCV mean score: {np.mean(sucrose_nXcv['mean_scores'])} \n# count common features: {len(sucrose_nXcv['common_features'])}")
tabulate(suc_term_count_cellc)
# Out:
# # <<< SUCROSE >>>
# # 10x3FoldCV mean score: 0.3188916665994363
# # count common features: 8
# count	GO ID	GO Term	namespace
# 1	GO:0006807	nitrogen compound metabolic process	biological_process
# 1	GO:0006974	DNA damage response	biological_process
# 1	GO:0043170	macromolecule metabolic process	biological_process
# 1	GO:0044238	primary metabolic process	biological_process
# 1	GO:0050794	regulation of cellular process	biological_process
# 1	GO:0006622	protein targeting to lysosome	biological_process
# 1	GO:0009306	protein secretion	biological_process
# 1	GO:0010324	membrane invagination	biological_process
# 1	GO:0010642	negative regulation of platelet-derived growth factor receptor signaling pathway	biological_process
# 1	GO:0016525	negative regulation of angiogenesis	biological_process
# 1	GO:0030948	negative regulation of vascular endothelial growth factor receptor signaling pathway	biological_process
# 1	GO:0043162	ubiquitin-dependent protein catabolic process via the multivesicular body sorting pathway	biological_process
# 1	GO:0043405	regulation of MAP kinase activity	biological_process
# 1	GO:0045053	protein retention in Golgi apparatus	biological_process
# 1	GO:0045324	late endosome to vacuole transport	biological_process
# 1	GO:0046426	negative regulation of receptor signaling pathway via JAK-STAT	biological_process
# 1	GO:0071985	multivesicular body sorting pathway	biological_process
# 1	GO:0072657	protein localization to membrane	biological_process
# 1	GO:0140504	microlipophagy	biological_process
# 1	GO:1903319	positive regulation of protein maturation	biological_process
# 1	GO:1903543	positive regulation of exosomal secretion	biological_process
# 1	GO:1904669	ATP export	biological_process
# 1	GO:0006508	proteolysis	biological_process
# 1	GO:0009567	double fertilization forming a zygote and endosperm	biological_process
# 1	GO:0009609	response to symbiotic bacterium	biological_process
# 1	GO:0009610	response to symbiotic fungus	biological_process
# 1	GO:0009682	induced systemic resistance	biological_process
# 1	GO:0009733	response to auxin	biological_process
# 1	GO:0009860	pollen tube growth	biological_process
# 1	GO:0010102	lateral root morphogenesis	biological_process
# 1	GO:0005975	carbohydrate metabolic process	biological_process
# 1	GO:0006119	oxidative phosphorylation	biological_process
# 1	GO:0022904	respiratory electron transport chain	biological_process
# 1	GO:0009620	response to fungus	biological_process
# 1	GO:0009693	ethylene biosynthetic process	biological_process
# 1	GO:0009727	detection of ethylene stimulus	biological_process
# 1	GO:0009835	fruit ripening	biological_process
# 1	GO:0010030	positive regulation of seed germination	biological_process
# 1	GO:0071398	cellular response to fatty acid	biological_process
# 1	GO:0071732	cellular response to nitric oxide	biological_process
# # <<< SUCROSE >>>
# # 10x3FoldCV mean score: 0.3188916665994363
# # count common features: 8
# count	GO ID	GO Term	namespace
# 1	GO:0019904	protein domain specific binding	molecular_function
# 1	GO:0032266	phosphatidylinositol-3-phosphate binding	molecular_function
# 1	GO:0042802	identical protein binding	molecular_function
# 1	GO:0043130	ubiquitin binding	molecular_function
# 1	GO:0044389	ubiquitin-like protein ligase binding	molecular_function
# 1	GO:0046982	protein heterodimerization activity	molecular_function
# 1	GO:0140036	ubiquitin-dependent protein binding	molecular_function
# 1	GO:0004252	serine-type endopeptidase activity	molecular_function
# 1	GO:0016791	phosphatase activity	molecular_function
# 1	GO:0009815	1-aminocyclopropane-1-carboxylate oxidase activity	molecular_function
# 1	GO:0031418	L-ascorbic acid binding	molecular_function
# 1	GO:0046872	metal ion binding	molecular_function
# 1	GO:0051213	dioxygenase activity	molecular_function
# # <<< SUCROSE >>>
# # 10x3FoldCV mean score: 0.3188916665994363
# # count common features: 8
# count	GO ID	GO Term	namespace
# 1	GO:0005634	nucleus	cellular_component
# 1	GO:0005764	lysosome	cellular_component
# 1	GO:0005769	early endosome	cellular_component
# 1	GO:0005774	vacuolar membrane	cellular_component
# 1	GO:0005829	cytosol	cellular_component
# 1	GO:0010008	endosome membrane	cellular_component
# 1	GO:0033565	ESCRT-0 complex	cellular_component
# 1	GO:0005576	extracellular region	cellular_component
# 1	GO:0005618	cell wall	cellular_component
# 1	GO:0031012	extracellular matrix	cellular_component
# 1	GO:0005737	cytoplasm	cellular_component
# 1	GO:0043231	intracellular membrane-bounded organelle	cellular_component
# 1	GO:0005747	mitochondrial respiratory chain complex I	cellular_component
# 1	GO:0005783	endoplasmic reticulum	cellular_component
# 1	GO:0005794	Golgi apparatus	cellular_component

# %%
"""PRINT EACH GFF ENTRY AND GO-TERMS CORRESPONDING TO NO-ZERO FEATURES"""

#for ele in sucrose_nXcv_matched:
#    print(f"{sucrose_nXcv_matched[ele]}")
#    #print(glucose_goids[ele], "\n")
#    for id in sucrose_goids[ele]:
#        print(id, ": ", sucrose_goids[ele][id])
# Out:
# 'PRINT EACH GFF ENTRY AND GO-TERMS CORRESPONDING TO NO-ZERO FEATURES'

# %% [markdown]
# ### citric acid

# %%
with open("./lasso_models/10xKfold_lasso_output/citricAcid_nXcv.json", 'r') as file:
    citricAcid_nXcv = json.load(file)
#citricAcid_nXcv_matched, citricAcid_goids, citricAcid_term_count, citricAcid_goea = matchgff2(citricAcid_nXcv['common_features'], goea=True)
citricAcid_nXcv_matched, citA_goids_biop, citA_term_count_biop, citA_goea_biop = matchgff2(citricAcid_nXcv['common_features'], namespace=['biological_process'], depth_threshold=2, goea=True)
citricAcid_nXcv_matched, citA_goids_molf, citA_term_count_molf, citA_goea_molf = matchgff2(citricAcid_nXcv['common_features'], namespace=['molecular_function'], depth_threshold=2, goea=True)
citricAcid_nXcv_matched, citA_goids_cellc, citA_term_count_cellc, citA_goea_cellc = matchgff2(citricAcid_nXcv['common_features'], namespace=['cellular_component'], depth_threshold=2, goea=True)
# Out:
# /home/t44p/PW_rawdata/go_obo/go.obo: fmt(1.2) rel(2023-11-15) 46,228 Terms
# GO Enrichment Analysis >>
#
# Load  Ontology Enrichment Analysis ...
#   0%    324 of 549,396 population items found in association
#
# Runing  Ontology Analysis: current study set of 18 IDs.
# 100%     18 of     18 study items found in association
# 100%     18 of     18 study items found in population(549396)
# Calculating 190 uncorrected p-values using fisher_scipy_stats
#      190 terms are associated with     13 of 549,396 population items
#      190 terms are associated with     13 of     18 study items
#   METHOD fdr_bh:
#      190 GO terms found significant (< 0.05=alpha) (190 enriched +   0 purified): statsmodels fdr_bh
#       13 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
# /home/t44p/PW_rawdata/go_obo/go.obo: fmt(1.2) rel(2023-11-15) 46,228 Terms
# GO Enrichment Analysis >>
#
# Load  Ontology Enrichment Analysis ...
#   0%    324 of 549,396 population items found in association
#
# Runing  Ontology Analysis: current study set of 18 IDs.
# 100%     18 of     18 study items found in association
# 100%     18 of     18 study items found in population(549396)
# Calculating 190 uncorrected p-values using fisher_scipy_stats
#      190 terms are associated with     13 of 549,396 population items
#      190 terms are associated with     13 of     18 study items
#   METHOD fdr_bh:
#      190 GO terms found significant (< 0.05=alpha) (190 enriched +   0 purified): statsmodels fdr_bh
#       13 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
# /home/t44p/PW_rawdata/go_obo/go.obo: fmt(1.2) rel(2023-11-15) 46,228 Terms
# GO Enrichment Analysis >>
#
# Load  Ontology Enrichment Analysis ...
#   0%    324 of 549,396 population items found in association
#
# Runing  Ontology Analysis: current study set of 18 IDs.
# 100%     18 of     18 study items found in association
# 100%     18 of     18 study items found in population(549396)
# Calculating 190 uncorrected p-values using fisher_scipy_stats
#      190 terms are associated with     13 of 549,396 population items
#      190 terms are associated with     13 of     18 study items
#   METHOD fdr_bh:
#      190 GO terms found significant (< 0.05=alpha) (190 enriched +   0 purified): statsmodels fdr_bh
#       13 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)

# %%
#plot_go_terms(citricAcid_term_count, top_n=10)
print("# <<< CITRIC ACID >>>")
print(f"# 10x3FoldCV mean score: {np.mean(citricAcid_nXcv['mean_scores'])} \n# count common features: {len(citricAcid_nXcv['common_features'])}")
tabulate(citA_term_count_biop)
print("# <<< CITRIC ACID >>>")
print(f"# 10x3FoldCV mean score: {np.mean(citricAcid_nXcv['mean_scores'])} \n# count common features: {len(citricAcid_nXcv['common_features'])}")
tabulate(citA_term_count_molf)
print("# <<< CITRIC ACID >>>")
print(f"# 10x3FoldCV mean score: {np.mean(citricAcid_nXcv['mean_scores'])} \n# count common features: {len(citricAcid_nXcv['common_features'])}")
tabulate(citA_term_count_cellc)
# Out:
# # <<< CITRIC ACID >>>
# # 10x3FoldCV mean score: 0.22358901669508696
# # count common features: 18
# count	GO ID	GO Term	namespace
# 2	GO:0009686	gibberellin biosynthetic process	biological_process
# 2	GO:0009826	unidimensional cell growth	biological_process
# 2	GO:0048235	pollen sperm cell differentiation	biological_process
# 2	GO:0055085	transmembrane transport	biological_process
# 1	GO:0009750	response to fructose	biological_process
# 1	GO:0090333	regulation of stomatal closure	biological_process
# 1	GO:0010182	sugar mediated signaling pathway	biological_process
# 1	GO:0007254	JNK cascade	biological_process
# 1	GO:0042733	embryonic digit morphogenesis	biological_process
# 1	GO:0001666	response to hypoxia	biological_process
# 1	GO:2000035	regulation of stem cell division	biological_process
# 1	GO:1904291	positive regulation of mitotic DNA damage checkpoint	biological_process
# 1	GO:0036289	peptidyl-serine autophosphorylation	biological_process
# 1	GO:0038066	p38MAPK cascade	biological_process
# 1	GO:1900424	regulation of defense response to bacterium	biological_process
# 1	GO:0071480	cellular response to gamma radiation	biological_process
# 1	GO:0097696	receptor signaling pathway via STAT	biological_process
# 1	GO:0071244	cellular response to carbon dioxide	biological_process
# 1	GO:0010105	negative regulation of ethylene-activated signaling pathway	biological_process
# 1	GO:0050765	negative regulation of phagocytosis	biological_process
# 1	GO:1900150	regulation of defense response to fungus	biological_process
# 1	GO:0009651	response to salt stress	biological_process
# 1	GO:0009658	chloroplast organization	biological_process
# 1	GO:0009414	response to water deprivation	biological_process
# 1	GO:0006935	chemotaxis	biological_process
# 1	GO:0001845	phagolysosome assembly	biological_process
# 1	GO:0050829	defense response to Gram-negative bacterium	biological_process
# 1	GO:2000031	regulation of salicylic acid mediated signaling pathway	biological_process
# 1	GO:2000030	regulation of response to red or far red light	biological_process
# 1	GO:0009744	response to sucrose	biological_process
# 1	GO:0009788	negative regulation of abscisic acid-activated signaling pathway	biological_process
# 1	GO:0002229	defense response to oomycetes	biological_process
# 1	GO:0048510	regulation of timing of transition from vegetative to reproductive phase	biological_process
# 1	GO:0051593	response to folic acid	biological_process
# 1	GO:0043065	positive regulation of apoptotic process	biological_process
# 1	GO:2000146	negative regulation of cell motility	biological_process
# 1	GO:2000069	regulation of post-embryonic root development	biological_process
# 1	GO:0030036	actin cytoskeleton organization	biological_process
# 1	GO:0030435	sporulation resulting in formation of a cellular spore	biological_process
# 1	GO:0000963	mitochondrial RNA processing	biological_process
# 1	GO:0010214	seed coat development	biological_process
# 1	GO:0016554	cytidine to uridine editing	biological_process
# 1	GO:0031425	chloroplast RNA processing	biological_process
# 1	GO:0031426	polycistronic mRNA processing	biological_process
# 1	GO:0080156	mitochondrial mRNA modification	biological_process
# 1	GO:0140547	acquisition of seed longevity	biological_process
# 1	GO:1900865	chloroplast RNA modification	biological_process
# 1	GO:0000012	single strand break repair	biological_process
# 1	GO:0006260	DNA replication	biological_process
# 1	GO:0006302	double-strand break repair	biological_process
# 1	GO:0006357	regulation of transcription by RNA polymerase II	biological_process
# 1	GO:0006783	heme biosynthetic process	biological_process
# 1	GO:0006790	sulfur compound metabolic process	biological_process
# 1	GO:0009150	purine ribonucleotide metabolic process	biological_process
# 1	GO:0009585	red, far-red light phototransduction	biological_process
# 1	GO:0009704	de-etiolation	biological_process
# 1	GO:0009733	response to auxin	biological_process
# 1	GO:0009740	gibberellic acid mediated signaling pathway	biological_process
# 1	GO:0009959	negative gravitropism	biological_process
# 1	GO:0010100	negative regulation of photomorphogenesis	biological_process
# 1	GO:0010161	red light signaling pathway	biological_process
# 1	GO:0010187	negative regulation of seed germination	biological_process
# 1	GO:0010197	polar nucleus fusion	biological_process
# 1	GO:0015995	chlorophyll biosynthetic process	biological_process
# 1	GO:0031539	positive regulation of anthocyanin metabolic process	biological_process
# 1	GO:0042548	regulation of photosynthesis, light reaction	biological_process
# 1	GO:0045893	positive regulation of DNA-templated transcription	biological_process
# 1	GO:0048586	regulation of long-day photoperiodism, flowering	biological_process
# 1	GO:0048587	regulation of short-day photoperiodism, flowering	biological_process
# 1	GO:0048766	root hair initiation	biological_process
# 1	GO:0048767	root hair elongation	biological_process
# 1	GO:0080113	regulation of seed growth	biological_process
# 1	GO:0090229	negative regulation of red or far-red light signaling pathway	biological_process
# 1	GO:0090305	N/A	N/A
# 1	GO:1905421	regulation of plant organ morphogenesis	biological_process
# 1	GO:1990785	response to water-immersion restraint stress	biological_process
# 1	GO:2000032	regulation of secondary shoot formation	biological_process
# 1	GO:0006534	cysteine metabolic process	biological_process
# 1	GO:0010269	response to selenium ion	biological_process
# 1	GO:0006833	water transport	biological_process
# 1	GO:0007033	vacuole organization	biological_process
# 1	GO:0015840	urea transport	biological_process
# 1	GO:0048366	leaf development	biological_process
# 1	GO:0016579	protein deubiquitination	biological_process
# 1	GO:0031647	regulation of protein stability	biological_process
# 1	GO:0010506	regulation of autophagy	biological_process
# 1	GO:0006613	cotranslational protein targeting to membrane	biological_process
# 1	GO:0007409	axonogenesis	biological_process
# 1	GO:0045047	protein targeting to ER	biological_process
# 1	GO:0050708	regulation of protein secretion	biological_process
# 1	GO:0016573	histone acetylation	biological_process
# 1	GO:0000226	microtubule cytoskeleton organization	biological_process
# 1	GO:0009561	megagametogenesis	biological_process
# 1	GO:0055046	microgametogenesis	biological_process
# 1	GO:0008202	steroid metabolic process	biological_process
# 1	GO:0048316	seed development	biological_process
# 1	GO:1901564	organonitrogen compound metabolic process	biological_process
# 1	GO:0048519	negative regulation of biological process	biological_process
# 1	GO:0051641	cellular localization	biological_process
# 1	GO:0097006	regulation of plasma lipoprotein particle levels	biological_process
# 1	GO:0034204	lipid translocation	biological_process
# 1	GO:0010874	regulation of cholesterol efflux	biological_process
# 1	GO:0033993	response to lipid	biological_process
# 1	GO:0140352	export from cell	biological_process
# 1	GO:0031334	positive regulation of protein-containing complex assembly	biological_process
# 1	GO:2001140	positive regulation of phospholipid transport	biological_process
# 1	GO:0046903	secretion	biological_process
# 1	GO:0071705	nitrogen compound transport	biological_process
# 1	GO:0071827	plasma lipoprotein particle organization	biological_process
# 1	GO:0007165	signal transduction	biological_process
# 1	GO:0055088	lipid homeostasis	biological_process
# 1	GO:0006650	glycerophospholipid metabolic process	biological_process
# 1	GO:0006996	organelle organization	biological_process
# 1	GO:0009719	response to endogenous stimulus	biological_process
# 1	GO:0042908	xenobiotic transport	biological_process
# 1	GO:0032376	positive regulation of cholesterol transport	biological_process
# 1	GO:0019216	regulation of lipid metabolic process	biological_process
# 1	GO:0006123	mitochondrial electron transport, cytochrome c to oxygen	biological_process
# 1	GO:0035694	mitochondrial protein catabolic process	biological_process
# # <<< CITRIC ACID >>>
# # 10x3FoldCV mean score: 0.22358901669508696
# # count common features: 18
# count	GO ID	GO Term	namespace
# 3	GO:0005524	ATP binding	molecular_function
# 3	GO:0005515	protein binding	molecular_function
# 2	GO:0042802	identical protein binding	molecular_function
# 1	GO:0004706	JUN kinase kinase kinase activity	molecular_function
# 1	GO:0000287	magnesium ion binding	molecular_function
# 1	GO:0004713	protein tyrosine kinase activity	molecular_function
# 1	GO:0004712	protein serine/threonine/tyrosine kinase activity	molecular_function
# 1	GO:0097677	STAT family protein binding	molecular_function
# 1	GO:0003729	mRNA binding	molecular_function
# 1	GO:0004519	endonuclease activity	molecular_function
# 1	GO:0008270	zinc ion binding	molecular_function
# 1	GO:0000978	RNA polymerase II cis-regulatory region sequence-specific DNA binding	molecular_function
# 1	GO:0000981	DNA-binding transcription factor activity, RNA polymerase II-specific	molecular_function
# 1	GO:0003697	single-stranded DNA binding	molecular_function
# 1	GO:0003725	double-stranded RNA binding	molecular_function
# 1	GO:0010313	phytochrome binding	molecular_function
# 1	GO:0030983	mismatched DNA binding	molecular_function
# 1	GO:0033699	DNA 5'-adenosine monophosphate hydrolase activity	molecular_function
# 1	GO:0046872	metal ion binding	molecular_function
# 1	GO:0046983	protein dimerization activity	molecular_function
# 1	GO:0047627	adenylylsulfatase activity	molecular_function
# 1	GO:1990165	single-strand break-containing DNA binding	molecular_function
# 1	GO:0090305	N/A	N/A
# 1	GO:0009000	selenocysteine lyase activity	molecular_function
# 1	GO:0030170	pyridoxal phosphate binding	molecular_function
# 1	GO:0031071	cysteine desulfurase activity	molecular_function
# 1	GO:0015200	methylammonium transmembrane transporter activity	molecular_function
# 1	GO:0015204	urea transmembrane transporter activity	molecular_function
# 1	GO:0015250	water channel activity	molecular_function
# 1	GO:0008234	cysteine-type peptidase activity	molecular_function
# 1	GO:0003924	GTPase activity	molecular_function
# 1	GO:0005047	signal recognition particle binding	molecular_function
# 1	GO:0097159	organic cyclic compound binding	molecular_function
# 1	GO:1901363	heterocyclic compound binding	molecular_function
# 1	GO:0051011	microtubule minus-end binding	molecular_function
# 1	GO:0120013	lipid transfer activity	molecular_function
# 1	GO:0008525	phosphatidylcholine transporter activity	molecular_function
# 1	GO:0140359	ABC-type transporter activity	molecular_function
# 1	GO:0015245	fatty acid transmembrane transporter activity	molecular_function
# 1	GO:0140328	floppase activity	molecular_function
# # <<< CITRIC ACID >>>
# # 10x3FoldCV mean score: 0.22358901669508696
# # count common features: 18
# count	GO ID	GO Term	namespace
# 2	GO:0005789	endoplasmic reticulum membrane	cellular_component
# 2	GO:0005886	plasma membrane	cellular_component
# 2	GO:0005634	nucleus	cellular_component
# 2	GO:0005739	mitochondrion	cellular_component
# 2	GO:0016021	membrane	cellular_component
# 2	GO:0016020	membrane	cellular_component
# 1	GO:0032010	phagolysosome	cellular_component
# 1	GO:0005829	cytosol	cellular_component
# 1	GO:0012510	trans-Golgi network transport vesicle membrane	cellular_component
# 1	GO:0005769	early endosome	cellular_component
# 1	GO:0005802	trans-Golgi network	cellular_component
# 1	GO:0005938	cell cortex	cellular_component
# 1	GO:0030670	phagocytic vesicle membrane	cellular_component
# 1	GO:0009507	chloroplast	cellular_component
# 1	GO:0090305	N/A	N/A
# 1	GO:0009570	chloroplast stroma	cellular_component
# 1	GO:0032586	protein storage vacuole membrane	cellular_component
# 1	GO:0042807	central vacuole	cellular_component
# 1	GO:0090406	pollen tube	cellular_component
# 1	GO:0005737	cytoplasm	cellular_component
# 1	GO:0005654	nucleoplasm	cellular_component
# 1	GO:0035267	NuA4 histone acetyltransferase complex	cellular_component
# 1	GO:0005819	spindle	cellular_component
# 1	GO:0005874	microtubule	cellular_component
# 1	GO:0009524	phragmoplast	cellular_component
# 1	GO:0005770	late endosome	cellular_component
# 1	GO:0005794	Golgi apparatus	cellular_component
# 1	GO:0097208	alveolar lamellar body	cellular_component
# 1	GO:0005783	endoplasmic reticulum	cellular_component
# 1	GO:0005764	lysosome	cellular_component
# 1	GO:0097232	lamellar body membrane	cellular_component
# 1	GO:0031966	mitochondrial membrane	cellular_component

# %%
"""PRINT EACH GFF ENTRY AND GO-TERMS CORRESPONDING TO NO-ZERO FEATURES"""

#for ele in citricAcid_nXcv_matched:
#    print(f"{citricAcid_nXcv_matched[ele]}")
#    #print(glucose_goids[ele], "\n")
#    for id in citricAcid_goids[ele]:
#        print(id, ": ", citricAcid_goids[ele][id])
# Out:
# 'PRINT EACH GFF ENTRY AND GO-TERMS CORRESPONDING TO NO-ZERO FEATURES'

# %%
with open("./lasso_models/10xKfold_lasso_output/isoleucine_nXcv.json", 'r') as file:
    isoleucine_nXcv = json.load(file)
#isoleucine_nXcv_matched, isoleucine_goids, isoleucine_term_count, isoleucine_goea = matchgff2(isoleucine_nXcv['common_features'], goea=True) #['biological_process', 'molecular_function', 'cellular_component']
isoleucine_nXcv_matched, ile_goids_biop, ile_term_count_biop, ile_goea_biop = matchgff2(isoleucine_nXcv['common_features'], namespace=['biological_process', 'molecular_function'], depth_threshold=2, goea=True)
isoleucine_nXcv_matched, ile_goids_molf, ile_term_count_molf, ile_goea_molf = matchgff2(isoleucine_nXcv['common_features'], namespace=['molecular_function'], depth_threshold=2, goea=True)
isoleucine_nXcv_matched, ile_goids_cellc, ile_term_count_cellc, ile_goea_cellc = matchgff2(isoleucine_nXcv['common_features'], namespace=['cellular_component'], depth_threshold=2, goea=True)
# Out:
# /home/t44p/PW_rawdata/go_obo/go.obo: fmt(1.2) rel(2023-11-15) 46,228 Terms
# GO Enrichment Analysis >>
#
# Load  Ontology Enrichment Analysis ...
#   0%     81 of 274,698 population items found in association
#
# Runing  Ontology Analysis: current study set of 9 IDs.
# 100%      9 of      9 study items found in association
# 100%      9 of      9 study items found in population(274698)
# Calculating 136 uncorrected p-values using fisher_scipy_stats
#      136 terms are associated with      8 of 274,698 population items
#      136 terms are associated with      8 of      9 study items
#   METHOD fdr_bh:
#      136 GO terms found significant (< 0.05=alpha) (136 enriched +   0 purified): statsmodels fdr_bh
#        8 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
# /home/t44p/PW_rawdata/go_obo/go.obo: fmt(1.2) rel(2023-11-15) 46,228 Terms
# GO Enrichment Analysis >>
#
# Load  Ontology Enrichment Analysis ...
#   0%     81 of 274,698 population items found in association
#
# Runing  Ontology Analysis: current study set of 9 IDs.
# 100%      9 of      9 study items found in association
# 100%      9 of      9 study items found in population(274698)
# Calculating 136 uncorrected p-values using fisher_scipy_stats
#      136 terms are associated with      8 of 274,698 population items
#      136 terms are associated with      8 of      9 study items
#   METHOD fdr_bh:
#      136 GO terms found significant (< 0.05=alpha) (136 enriched +   0 purified): statsmodels fdr_bh
#        8 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
# /home/t44p/PW_rawdata/go_obo/go.obo: fmt(1.2) rel(2023-11-15) 46,228 Terms
# GO Enrichment Analysis >>
#
# Load  Ontology Enrichment Analysis ...
#   0%     81 of 274,698 population items found in association
#
# Runing  Ontology Analysis: current study set of 9 IDs.
# 100%      9 of      9 study items found in association
# 100%      9 of      9 study items found in population(274698)
# Calculating 136 uncorrected p-values using fisher_scipy_stats
#      136 terms are associated with      8 of 274,698 population items
#      136 terms are associated with      8 of      9 study items
#   METHOD fdr_bh:
#      136 GO terms found significant (< 0.05=alpha) (136 enriched +   0 purified): statsmodels fdr_bh
#        8 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)

# %%
# plot_go_terms(isoleucine_term_count, top_n=10)
print("# <<< ISOLEUCINE >>>")
print(f"# 10x3FoldCV mean score: {np.mean(isoleucine_nXcv['mean_scores'])} \n# count common features: {len(isoleucine_nXcv['common_features'])}")
tabulate(ile_term_count_biop)
print("# <<< ISOLEUCINE >>>")
print(f"# 10x3FoldCV mean score: {np.mean(isoleucine_nXcv['mean_scores'])} \n# count common features: {len(isoleucine_nXcv['common_features'])}")
tabulate(ile_term_count_molf)
print("# <<< ISOLEUCINE >>>")
print(f"# 10x3FoldCV mean score: {np.mean(isoleucine_nXcv['mean_scores'])} \n# count common features: {len(isoleucine_nXcv['common_features'])}")
tabulate(ile_term_count_cellc)
# Out:
# # <<< ISOLEUCINE >>>
# # 10x3FoldCV mean score: 0.07529144560758311
# # count common features: 9
# count	GO ID	GO Term	namespace
# 2	GO:0000166	nucleotide binding	molecular_function
# 2	GO:0050832	defense response to fungus	biological_process
# 2	GO:0042803	protein homodimerization activity	molecular_function
# 2	GO:0004674	protein serine/threonine kinase activity	molecular_function
# 2	GO:0005515	protein binding	molecular_function
# 2	GO:0045893	positive regulation of DNA-templated transcription	biological_process
# 2	GO:0009737	response to abscisic acid	biological_process
# 1	GO:0042910	xenobiotic transmembrane transporter activity	molecular_function
# 1	GO:0032370	positive regulation of lipid transport	biological_process
# 1	GO:0055076	N/A	N/A
# 1	GO:0009791	post-embryonic development	biological_process
# 1	GO:0051173	positive regulation of nitrogen compound metabolic process	biological_process
# 1	GO:0006820	monoatomic anion transport	biological_process
# 1	GO:1901700	response to oxygen-containing compound	biological_process
# 1	GO:0009733	response to auxin	biological_process
# 1	GO:0005524	ATP binding	molecular_function
# 1	GO:0005548	phospholipid transporter activity	molecular_function
# 1	GO:0009605	response to external stimulus	biological_process
# 1	GO:0071310	cellular response to organic substance	biological_process
# 1	GO:0034204	lipid translocation	biological_process
# 1	GO:0140115	export across plasma membrane	biological_process
# 1	GO:0033993	response to lipid	biological_process
# 1	GO:0042626	ATPase-coupled transmembrane transporter activity	molecular_function
# 1	GO:0042802	identical protein binding	molecular_function
# 1	GO:0014070	response to organic cyclic compound	biological_process
# 1	GO:0060918	auxin transport	biological_process
# 1	GO:0009639	response to red or far red light	biological_process
# 1	GO:0031328	positive regulation of cellular biosynthetic process	biological_process
# 1	GO:0048731	system development	biological_process
# 1	GO:0140328	floppase activity	molecular_function
# 1	GO:0015914	phospholipid transport	biological_process
# 1	GO:0042908	xenobiotic transport	biological_process
# 1	GO:0032491	detection of molecule of fungal origin	biological_process
# 1	GO:0008061	chitin binding	molecular_function
# 1	GO:0090333	regulation of stomatal closure	biological_process
# 1	GO:0046777	protein autophosphorylation	biological_process
# 1	GO:0048364	root development	biological_process
# 1	GO:0002752	cell surface pattern recognition receptor signaling pathway	biological_process
# 1	GO:0019722	calcium-mediated signaling	biological_process
# 1	GO:0071219	cellular response to molecule of bacterial origin	biological_process
# 1	GO:0015026	coreceptor activity	molecular_function
# 1	GO:0009862	systemic acquired resistance, salicylic acid mediated signaling pathway	biological_process
# 1	GO:2001080	chitosan binding	molecular_function
# 1	GO:1900425	negative regulation of defense response to bacterium	biological_process
# 1	GO:0009845	seed germination	biological_process
# 1	GO:1900426	positive regulation of defense response to bacterium	biological_process
# 1	GO:0007639	homeostasis of number of meristem cells	biological_process
# 1	GO:0004842	ubiquitin-protein transferase activity	molecular_function
# 1	GO:0009738	abscisic acid-activated signaling pathway	biological_process
# 1	GO:0002229	defense response to oomycetes	biological_process
# 1	GO:0048653	anther development	biological_process
# 1	GO:0140426	pathogen-associated molecular pattern receptor signaling pathway	biological_process
# 1	GO:0019199	transmembrane receptor protein kinase activity	molecular_function
# 1	GO:0010726	positive regulation of hydrogen peroxide metabolic process	biological_process
# 1	GO:0032499	detection of peptidoglycan	biological_process
# 1	GO:0071323	cellular response to chitin	biological_process
# 1	GO:0010942	N/A	N/A
# 1	GO:0016567	protein ubiquitination	biological_process
# 1	GO:0005375	copper ion transmembrane transporter activity	molecular_function
# 1	GO:0005381	iron ion transmembrane transporter activity	molecular_function
# 1	GO:0005385	zinc ion transmembrane transporter activity	molecular_function
# 1	GO:0006826	iron ion transport	biological_process
# 1	GO:0009617	response to bacterium	biological_process
# 1	GO:0010043	response to zinc ion	biological_process
# 1	GO:0015675	nickel cation transport	biological_process
# 1	GO:0071577	zinc ion transmembrane transport	biological_process
# 1	GO:0030176	N/A	N/A
# 1	GO:0004252	serine-type endopeptidase activity	molecular_function
# 1	GO:0051787	misfolded protein binding	molecular_function
# 1	GO:1990381	ubiquitin-specific protease binding	molecular_function
# 1	GO:0007283	spermatogenesis	biological_process
# 1	GO:0030154	cell differentiation	biological_process
# 1	GO:0030433	ubiquitin-dependent ERAD pathway	biological_process
# 1	GO:0030968	endoplasmic reticulum unfolded protein response	biological_process
# 1	GO:0033619	membrane protein proteolysis	biological_process
# 1	GO:0051247	positive regulation of protein metabolic process	biological_process
# 1	GO:1902074	response to salt	biological_process
# 1	GO:0009651	response to salt stress	biological_process
# 1	GO:0090058	metaxylem development	biological_process
# 1	GO:0090059	protoxylem development	biological_process
# 1	GO:0043068	positive regulation of programmed cell death	biological_process
# 1	GO:0000976	transcription cis-regulatory region binding	molecular_function
# 1	GO:1900057	positive regulation of leaf senescence	biological_process
# 1	GO:0051091	positive regulation of DNA-binding transcription factor activity	biological_process
# 1	GO:1901348	positive regulation of secondary cell wall biogenesis	biological_process
# 1	GO:0009735	response to cytokinin	biological_process
# 1	GO:0048759	xylem vessel member cell differentiation	biological_process
# 1	GO:0009734	auxin-activated signaling pathway	biological_process
# 1	GO:1903648	positive regulation of chlorophyll catabolic process	biological_process
# 1	GO:1990110	callus formation	biological_process
# 1	GO:0003700	DNA-binding transcription factor activity	molecular_function
# 1	GO:0045491	xylan metabolic process	biological_process
# 1	GO:0046982	protein heterodimerization activity	molecular_function
# 1	GO:0051782	negative regulation of cell division	biological_process
# 1	GO:0071555	cell wall organization	biological_process
# 1	GO:1904250	positive regulation of age-related resistance	biological_process
# 1	GO:0010199	organ boundary specification between lateral organs and the meristem	biological_process
# 1	GO:0048829	root cap development	biological_process
# 1	GO:0090400	stress-induced premature senescence	biological_process
# 1	GO:0080187	floral organ senescence	biological_process
# 1	GO:0010072	primary shoot apical meristem specification	biological_process
# 1	GO:0009741	response to brassinosteroid	biological_process
# 1	GO:0042542	response to hydrogen peroxide	biological_process
# 1	GO:0009723	response to ethylene	biological_process
# 1	GO:0048527	lateral root development	biological_process
# 1	GO:0010628	positive regulation of gene expression	biological_process
# 1	GO:0090709	regulation of timing of plant organ formation	biological_process
# 1	GO:0010029	regulation of seed germination	biological_process
# 1	GO:0010981	regulation of cell wall macromolecule metabolic process	biological_process
# 1	GO:0010223	secondary shoot formation	biological_process
# 1	GO:0045739	positive regulation of DNA repair	biological_process
# 1	GO:0043967	histone H4 acetylation	biological_process
# 1	GO:1900095	N/A	N/A
# 1	GO:0051053	negative regulation of DNA metabolic process	biological_process
# 1	GO:0003727	single-stranded RNA binding	molecular_function
# 1	GO:0045995	regulation of embryonic development	biological_process
# 1	GO:1904507	positive regulation of telomere maintenance in response to DNA damage	biological_process
# 1	GO:0002237	response to molecule of bacterial origin	biological_process
# 1	GO:0006468	protein phosphorylation	biological_process
# 1	GO:0009625	response to insect	biological_process
# 1	GO:0042742	defense response to bacterium	biological_process
# 1	GO:0050826	response to freezing	biological_process
# # <<< ISOLEUCINE >>>
# # 10x3FoldCV mean score: 0.07529144560758311
# # count common features: 9
# count	GO ID	GO Term	namespace
# 2	GO:0000166	nucleotide binding	molecular_function
# 2	GO:0042803	protein homodimerization activity	molecular_function
# 2	GO:0004674	protein serine/threonine kinase activity	molecular_function
# 2	GO:0005515	protein binding	molecular_function
# 1	GO:0042910	xenobiotic transmembrane transporter activity	molecular_function
# 1	GO:0055076	N/A	N/A
# 1	GO:0005524	ATP binding	molecular_function
# 1	GO:0005548	phospholipid transporter activity	molecular_function
# 1	GO:0042626	ATPase-coupled transmembrane transporter activity	molecular_function
# 1	GO:0042802	identical protein binding	molecular_function
# 1	GO:0140328	floppase activity	molecular_function
# 1	GO:0008061	chitin binding	molecular_function
# 1	GO:0015026	coreceptor activity	molecular_function
# 1	GO:2001080	chitosan binding	molecular_function
# 1	GO:0004842	ubiquitin-protein transferase activity	molecular_function
# 1	GO:0019199	transmembrane receptor protein kinase activity	molecular_function
# 1	GO:0010942	N/A	N/A
# 1	GO:0005375	copper ion transmembrane transporter activity	molecular_function
# 1	GO:0005381	iron ion transmembrane transporter activity	molecular_function
# 1	GO:0005385	zinc ion transmembrane transporter activity	molecular_function
# 1	GO:0030176	N/A	N/A
# 1	GO:0004252	serine-type endopeptidase activity	molecular_function
# 1	GO:0051787	misfolded protein binding	molecular_function
# 1	GO:1990381	ubiquitin-specific protease binding	molecular_function
# 1	GO:0000976	transcription cis-regulatory region binding	molecular_function
# 1	GO:0003700	DNA-binding transcription factor activity	molecular_function
# 1	GO:0046982	protein heterodimerization activity	molecular_function
# 1	GO:1900095	N/A	N/A
# 1	GO:0003727	single-stranded RNA binding	molecular_function
# # <<< ISOLEUCINE >>>
# # 10x3FoldCV mean score: 0.07529144560758311
# # count common features: 9
# count	GO ID	GO Term	namespace
# 4	GO:0005886	plasma membrane	cellular_component
# 2	GO:0016021	membrane	cellular_component
# 2	GO:0005737	cytoplasm	cellular_component
# 1	GO:0055076	N/A	N/A
# 1	GO:0009706	chloroplast inner membrane	cellular_component
# 1	GO:0005911	cell-cell junction	cellular_component
# 1	GO:0031966	mitochondrial membrane	cellular_component
# 1	GO:0012505	endomembrane system	cellular_component
# 1	GO:0010942	N/A	N/A
# 1	GO:0005768	endosome	cellular_component
# 1	GO:0005773	vacuole	cellular_component
# 1	GO:0005802	trans-Golgi network	cellular_component
# 1	GO:0009507	chloroplast	cellular_component
# 1	GO:0009579	thylakoid	cellular_component
# 1	GO:0000839	Hrd1p ubiquitin ligase ERAD-L complex	cellular_component
# 1	GO:0030176	N/A	N/A
# 1	GO:0009531	secondary cell wall	cellular_component
# 1	GO:0005634	nucleus	cellular_component
# 1	GO:1900095	N/A	N/A
# 1	GO:0043232	intracellular non-membrane-bounded organelle	cellular_component
# 1	GO:0000123	histone acetyltransferase complex	cellular_component

# %%
with open("./lasso_models/10xKfold_lasso_output/leucine_nXcv.json", 'r') as file:
    leucine_nXcv = json.load(file)
#leucine_nXcv_matched, leucine_goids, leucine_term_count, leucine_goea = matchgff2(leucine_nXcv['common_features'], goea=True)
leucine_nXcv_matched, leu_goids_biop, leu_term_count_biop, leu_goea_biop = matchgff2(leucine_nXcv['common_features'], namespace=['biological_process', 'molecular_function'], depth_threshold=2, goea=True)
leucine_nXcv_matched, leu_goids_molf, leu_term_count_molf, leu_goea_molf = matchgff2(leucine_nXcv['common_features'], namespace=['molecular_function'], depth_threshold=2, goea=True)
leucine_nXcv_matched, leu_goids_cellc, leu_term_count_cellc, leu_goea_cellc = matchgff2(leucine_nXcv['common_features'], namespace=['cellular_component'], depth_threshold=2, goea=True)
# Out:
# /home/t44p/PW_rawdata/go_obo/go.obo: fmt(1.2) rel(2023-11-15) 46,228 Terms
# GO Enrichment Analysis >>
#
# Load  Ontology Enrichment Analysis ...
#   0%    225 of 457,830 population items found in association
#
# Runing  Ontology Analysis: current study set of 15 IDs.
# 100%     15 of     15 study items found in association
# 100%     15 of     15 study items found in population(457830)
# Calculating 119 uncorrected p-values using fisher_scipy_stats
#      119 terms are associated with     11 of 457,830 population items
#      119 terms are associated with     11 of     15 study items
#   METHOD fdr_bh:
#      119 GO terms found significant (< 0.05=alpha) (119 enriched +   0 purified): statsmodels fdr_bh
#       11 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
# /home/t44p/PW_rawdata/go_obo/go.obo: fmt(1.2) rel(2023-11-15) 46,228 Terms
# GO Enrichment Analysis >>
#
# Load  Ontology Enrichment Analysis ...
#   0%    225 of 457,830 population items found in association
#
# Runing  Ontology Analysis: current study set of 15 IDs.
# 100%     15 of     15 study items found in association
# 100%     15 of     15 study items found in population(457830)
# Calculating 119 uncorrected p-values using fisher_scipy_stats
#      119 terms are associated with     11 of 457,830 population items
#      119 terms are associated with     11 of     15 study items
#   METHOD fdr_bh:
#      119 GO terms found significant (< 0.05=alpha) (119 enriched +   0 purified): statsmodels fdr_bh
#       11 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
# /home/t44p/PW_rawdata/go_obo/go.obo: fmt(1.2) rel(2023-11-15) 46,228 Terms
# GO Enrichment Analysis >>
#
# Load  Ontology Enrichment Analysis ...
#   0%    225 of 457,830 population items found in association
#
# Runing  Ontology Analysis: current study set of 15 IDs.
# 100%     15 of     15 study items found in association
# 100%     15 of     15 study items found in population(457830)
# Calculating 119 uncorrected p-values using fisher_scipy_stats
#      119 terms are associated with     11 of 457,830 population items
#      119 terms are associated with     11 of     15 study items
#   METHOD fdr_bh:
#      119 GO terms found significant (< 0.05=alpha) (119 enriched +   0 purified): statsmodels fdr_bh
#       11 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)

# %%
# plot_go_terms(leucine_term_count, top_n=10)
print("# <<< LEUCINE >>>")
print(f"# 10x3FoldCV mean score: {np.mean(leucine_nXcv['mean_scores'])} \n# count common features: {len(leucine_nXcv['common_features'])}")
tabulate(leu_term_count_biop)
print("# <<< LEUCINE >>>")
print(f"# 10x3FoldCV mean score: {np.mean(leucine_nXcv['mean_scores'])} \n# count common features: {len(leucine_nXcv['common_features'])}")
tabulate(leu_term_count_molf)
tabulate(leu_term_count_cellc)
# Out:
# # <<< LEUCINE >>>
# # 10x3FoldCV mean score: 0.39988802939102847
# # count common features: 15
# count	GO ID	GO Term	namespace
# 6	GO:0005515	protein binding	molecular_function
# 3	GO:0004674	protein serine/threonine kinase activity	molecular_function
# 2	GO:0046777	protein autophosphorylation	biological_process
# 2	GO:0048364	root development	biological_process
# 2	GO:0000166	nucleotide binding	molecular_function
# 2	GO:0019722	calcium-mediated signaling	biological_process
# 2	GO:0009845	seed germination	biological_process
# 2	GO:0009738	abscisic acid-activated signaling pathway	biological_process
# 2	GO:0002237	response to molecule of bacterial origin	biological_process
# 2	GO:0009625	response to insect	biological_process
# 2	GO:0042742	defense response to bacterium	biological_process
# 2	GO:0050826	response to freezing	biological_process
# 1	GO:0016018	cyclosporin A binding	molecular_function
# 1	GO:0009742	brassinosteroid mediated signaling pathway	biological_process
# 1	GO:0000413	protein peptidyl-prolyl isomerization	biological_process
# 1	GO:0009414	response to water deprivation	biological_process
# 1	GO:0003755	peptidyl-prolyl cis-trans isomerase activity	molecular_function
# 1	GO:0061083	regulation of protein refolding	biological_process
# 1	GO:0007623	circadian rhythm	biological_process
# 1	GO:0071482	cellular response to light stimulus	biological_process
# 1	GO:0032491	detection of molecule of fungal origin	biological_process
# 1	GO:0008061	chitin binding	molecular_function
# 1	GO:0090333	regulation of stomatal closure	biological_process
# 1	GO:0002752	cell surface pattern recognition receptor signaling pathway	biological_process
# 1	GO:0071219	cellular response to molecule of bacterial origin	biological_process
# 1	GO:0050832	defense response to fungus	biological_process
# 1	GO:0015026	coreceptor activity	molecular_function
# 1	GO:0042803	protein homodimerization activity	molecular_function
# 1	GO:0009862	systemic acquired resistance, salicylic acid mediated signaling pathway	biological_process
# 1	GO:2001080	chitosan binding	molecular_function
# 1	GO:1900425	negative regulation of defense response to bacterium	biological_process
# 1	GO:1900426	positive regulation of defense response to bacterium	biological_process
# 1	GO:0007639	homeostasis of number of meristem cells	biological_process
# 1	GO:0004842	ubiquitin-protein transferase activity	molecular_function
# 1	GO:0002229	defense response to oomycetes	biological_process
# 1	GO:0048653	anther development	biological_process
# 1	GO:0140426	pathogen-associated molecular pattern receptor signaling pathway	biological_process
# 1	GO:0019199	transmembrane receptor protein kinase activity	molecular_function
# 1	GO:0010726	positive regulation of hydrogen peroxide metabolic process	biological_process
# 1	GO:0032499	detection of peptidoglycan	biological_process
# 1	GO:0071323	cellular response to chitin	biological_process
# 1	GO:0010942	N/A	N/A
# 1	GO:0016567	protein ubiquitination	biological_process
# 1	GO:0003677	DNA binding	molecular_function
# 1	GO:0008094	ATP-dependent activity, acting on DNA	molecular_function
# 1	GO:0016787	hydrolase activity	molecular_function
# 1	GO:0001701	in utero embryonic development	biological_process
# 1	GO:0006312	mitotic recombination	biological_process
# 1	GO:0007131	reciprocal meiotic recombination	biological_process
# 1	GO:0022607	cellular component assembly	biological_process
# 1	GO:0045003	double-strand break repair via synthesis-dependent strand annealing	biological_process
# 1	GO:0051128	regulation of cellular component organization	biological_process
# 1	GO:0090068	positive regulation of cell cycle process	biological_process
# 1	GO:0090737	telomere maintenance via telomere trimming	biological_process
# 1	GO:1901990	regulation of mitotic cell cycle phase transition	biological_process
# 1	GO:0019901	protein kinase binding	molecular_function
# 1	GO:0002221	pattern recognition receptor signaling pathway	biological_process
# 1	GO:0045087	innate immune response	biological_process
# 1	GO:1900459	positive regulation of brassinosteroid mediated signaling pathway	biological_process
# 1	GO:0000978	RNA polymerase II cis-regulatory region sequence-specific DNA binding	molecular_function
# 1	GO:0000981	DNA-binding transcription factor activity, RNA polymerase II-specific	molecular_function
# 1	GO:0006357	regulation of transcription by RNA polymerase II	biological_process
# 1	GO:0009416	response to light stimulus	biological_process
# 1	GO:0009722	detection of cytokinin stimulus	biological_process
# 1	GO:0009727	detection of ethylene stimulus	biological_process
# 1	GO:0010089	xylem development	biological_process
# 1	GO:0010192	mucilage biosynthetic process	biological_process
# 1	GO:0010214	seed coat development	biological_process
# 1	GO:0045892	negative regulation of DNA-templated transcription	biological_process
# 1	GO:0048437	floral organ development	biological_process
# 1	GO:0048438	floral whorl development	biological_process
# 1	GO:0048827	phyllome development	biological_process
# 1	GO:0071345	cellular response to cytokine stimulus	biological_process
# 1	GO:0071369	cellular response to ethylene stimulus	biological_process
# 1	GO:0080001	mucilage extrusion from seed coat	biological_process
# 1	GO:0080112	seed growth	biological_process
# 1	GO:2000652	regulation of secondary cell wall biogenesis	biological_process
# 1	GO:0006810	transport	biological_process
# 1	GO:0019058	viral life cycle	biological_process
# 1	GO:0030154	cell differentiation	biological_process
# 1	GO:0031323	regulation of cellular metabolic process	biological_process
# 1	GO:0048523	negative regulation of cellular process	biological_process
# 1	GO:0051171	regulation of nitrogen compound metabolic process	biological_process
# 1	GO:0060255	regulation of macromolecule metabolic process	biological_process
# 1	GO:0080090	regulation of primary metabolic process	biological_process
# 1	GO:0003729	mRNA binding	molecular_function
# 1	GO:0003735	structural constituent of ribosome	molecular_function
# 1	GO:0002181	cytoplasmic translation	biological_process
# 1	GO:0016236	macroautophagy	biological_process
# 1	GO:0042273	ribosomal large subunit biogenesis	biological_process
# 1	GO:0006468	protein phosphorylation	biological_process
# 1	GO:0009737	response to abscisic acid	biological_process
# 1	GO:0008168	methyltransferase activity	molecular_function
# 1	GO:0000154	rRNA modification	biological_process
# 1	GO:0001510	RNA methylation	biological_process
# count	GO ID	GO Term	namespace
# 6	GO:0005515	protein binding	molecular_function
# 3	GO:0004674	protein serine/threonine kinase activity	molecular_function
# 2	GO:0000166	nucleotide binding	molecular_function
# 1	GO:0016018	cyclosporin A binding	molecular_function
# 1	GO:0003755	peptidyl-prolyl cis-trans isomerase activity	molecular_function
# 1	GO:0008061	chitin binding	molecular_function
# 1	GO:0015026	coreceptor activity	molecular_function
# 1	GO:0042803	protein homodimerization activity	molecular_function
# 1	GO:2001080	chitosan binding	molecular_function
# 1	GO:0004842	ubiquitin-protein transferase activity	molecular_function
# 1	GO:0019199	transmembrane receptor protein kinase activity	molecular_function
# 1	GO:0010942	N/A	N/A
# 1	GO:0003677	DNA binding	molecular_function
# 1	GO:0008094	ATP-dependent activity, acting on DNA	molecular_function
# 1	GO:0016787	hydrolase activity	molecular_function
# 1	GO:0019901	protein kinase binding	molecular_function
# 1	GO:0000978	RNA polymerase II cis-regulatory region sequence-specific DNA binding	molecular_function
# 1	GO:0000981	DNA-binding transcription factor activity, RNA polymerase II-specific	molecular_function
# 1	GO:0003729	mRNA binding	molecular_function
# 1	GO:0003735	structural constituent of ribosome	molecular_function
# 1	GO:0008168	methyltransferase activity	molecular_function
# count	GO ID	GO Term	namespace
# 3	GO:0005886	plasma membrane	cellular_component
# 2	GO:0005829	cytosol	cellular_component
# 1	GO:0005783	endoplasmic reticulum	cellular_component
# 1	GO:0005771	multivesicular body	cellular_component
# 1	GO:0005576	extracellular region	cellular_component
# 1	GO:0005795	Golgi stack	cellular_component
# 1	GO:0016020	membrane	cellular_component
# 1	GO:0009570	chloroplast stroma	cellular_component
# 1	GO:0009941	chloroplast envelope	cellular_component
# 1	GO:0098807	chloroplast thylakoid membrane protein complex	cellular_component
# 1	GO:0010942	N/A	N/A
# 1	GO:0005654	nucleoplasm	cellular_component
# 1	GO:0005694	chromosome	cellular_component
# 1	GO:0005739	mitochondrion	cellular_component
# 1	GO:0033061	DNA recombinase mediator complex	cellular_component
# 1	GO:0140513	nuclear protein-containing complex	cellular_component
# 1	GO:0005777	peroxisome	cellular_component
# 1	GO:0005634	nucleus	cellular_component
# 1	GO:0005770	late endosome	cellular_component
# 1	GO:0010008	endosome membrane	cellular_component
# 1	GO:0043232	intracellular non-membrane-bounded organelle	cellular_component
# 1	GO:0014069	postsynaptic density	cellular_component
# 1	GO:0022625	cytosolic large ribosomal subunit	cellular_component
# 1	GO:0042788	polysomal ribosome	cellular_component
# 1	GO:0098556	cytoplasmic side of rough endoplasmic reticulum membrane	cellular_component

# %%
with open("./lasso_models/10xKfold_lasso_output/valine_nXcv.json", 'r') as file:
    valine_nXcv = json.load(file)
#valine_nXcv_matched, valine_goids, valine_term_count, valine_goea = matchgff2(valine_nXcv['common_features'], goea=True)
valine_nXcv_matched, val_goids_biop, val_term_count_biop, val_goea_biop = matchgff2(valine_nXcv['common_features'], namespace=['biological_process', 'molecular_function'], depth_threshold=2, goea=True)
valine_nXcv_matched, val_goids_molf, val_term_count_molf, val_goea_molf = matchgff2(valine_nXcv['common_features'], namespace=['molecular_function'], depth_threshold=2, goea=True)
valine_nXcv_matched, val_goids_cellc, val_term_count_cellc, val_goea_cellc = matchgff2(valine_nXcv['common_features'], namespace=['cellular_component'], depth_threshold=2, goea=True)
# Out:
# /home/t44p/PW_rawdata/go_obo/go.obo: fmt(1.2) rel(2023-11-15) 46,228 Terms
# GO Enrichment Analysis >>
#
# Load  Ontology Enrichment Analysis ...
#   0%    169 of 396,786 population items found in association
#
# Runing  Ontology Analysis: current study set of 13 IDs.
# 100%     13 of     13 study items found in association
# 100%     13 of     13 study items found in population(396786)
# Calculating 186 uncorrected p-values using fisher_scipy_stats
#      186 terms are associated with     12 of 396,786 population items
#      186 terms are associated with     12 of     13 study items
#   METHOD fdr_bh:
#      186 GO terms found significant (< 0.05=alpha) (186 enriched +   0 purified): statsmodels fdr_bh
#       12 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
# /home/t44p/PW_rawdata/go_obo/go.obo: fmt(1.2) rel(2023-11-15) 46,228 Terms
# GO Enrichment Analysis >>
#
# Load  Ontology Enrichment Analysis ...
#   0%    169 of 396,786 population items found in association
#
# Runing  Ontology Analysis: current study set of 13 IDs.
# 100%     13 of     13 study items found in association
# 100%     13 of     13 study items found in population(396786)
# Calculating 186 uncorrected p-values using fisher_scipy_stats
#      186 terms are associated with     12 of 396,786 population items
#      186 terms are associated with     12 of     13 study items
#   METHOD fdr_bh:
#      186 GO terms found significant (< 0.05=alpha) (186 enriched +   0 purified): statsmodels fdr_bh
#       12 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
# /home/t44p/PW_rawdata/go_obo/go.obo: fmt(1.2) rel(2023-11-15) 46,228 Terms
# GO Enrichment Analysis >>
#
# Load  Ontology Enrichment Analysis ...
#   0%    169 of 396,786 population items found in association
#
# Runing  Ontology Analysis: current study set of 13 IDs.
# 100%     13 of     13 study items found in association
# 100%     13 of     13 study items found in population(396786)
# Calculating 186 uncorrected p-values using fisher_scipy_stats
#      186 terms are associated with     12 of 396,786 population items
#      186 terms are associated with     12 of     13 study items
#   METHOD fdr_bh:
#      186 GO terms found significant (< 0.05=alpha) (186 enriched +   0 purified): statsmodels fdr_bh
#       12 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)

# %%
#plot_go_terms(valine_term_count, top_n=10)
print("# <<< VALINE >>>")
print(f"# 10x3FoldCV mean score: {np.mean(valine_nXcv['mean_scores'])} \n# count common features: {len(valine_nXcv['common_features'])}")
tabulate(val_term_count_biop)
tabulate(val_term_count_molf)
tabulate(val_term_count_cellc)
# Out:
# # <<< VALINE >>>
# # 10x3FoldCV mean score: 0.4303056564518039
# # count common features: 13
# count	GO ID	GO Term	namespace
# 2	GO:0046777	protein autophosphorylation	biological_process
# 2	GO:0000166	nucleotide binding	molecular_function
# 2	GO:0016567	protein ubiquitination	biological_process
# 2	GO:0051787	misfolded protein binding	molecular_function
# 2	GO:0051015	actin filament binding	molecular_function
# 1	GO:0032491	detection of molecule of fungal origin	biological_process
# 1	GO:0008061	chitin binding	molecular_function
# 1	GO:0090333	regulation of stomatal closure	biological_process
# 1	GO:0048364	root development	biological_process
# 1	GO:0002752	cell surface pattern recognition receptor signaling pathway	biological_process
# 1	GO:0019722	calcium-mediated signaling	biological_process
# 1	GO:0071219	cellular response to molecule of bacterial origin	biological_process
# 1	GO:0050832	defense response to fungus	biological_process
# 1	GO:0015026	coreceptor activity	molecular_function
# 1	GO:0042803	protein homodimerization activity	molecular_function
# 1	GO:0009862	systemic acquired resistance, salicylic acid mediated signaling pathway	biological_process
# 1	GO:2001080	chitosan binding	molecular_function
# 1	GO:0004674	protein serine/threonine kinase activity	molecular_function
# 1	GO:1900425	negative regulation of defense response to bacterium	biological_process
# 1	GO:0009845	seed germination	biological_process
# 1	GO:1900426	positive regulation of defense response to bacterium	biological_process
# 1	GO:0007639	homeostasis of number of meristem cells	biological_process
# 1	GO:0004842	ubiquitin-protein transferase activity	molecular_function
# 1	GO:0009738	abscisic acid-activated signaling pathway	biological_process
# 1	GO:0002229	defense response to oomycetes	biological_process
# 1	GO:0048653	anther development	biological_process
# 1	GO:0140426	pathogen-associated molecular pattern receptor signaling pathway	biological_process
# 1	GO:0019199	transmembrane receptor protein kinase activity	molecular_function
# 1	GO:0010726	positive regulation of hydrogen peroxide metabolic process	biological_process
# 1	GO:0032499	detection of peptidoglycan	biological_process
# 1	GO:0071323	cellular response to chitin	biological_process
# 1	GO:0010942	N/A	N/A
# 1	GO:0006457	protein folding	biological_process
# 1	GO:0005515	protein binding	molecular_function
# 1	GO:0016210	naringenin-chalcone synthase activity	molecular_function
# 1	GO:0090439	tetraketide alpha-pyrone synthase activity	molecular_function
# 1	GO:0009813	flavonoid biosynthetic process	biological_process
# 1	GO:0030639	polyketide biosynthetic process	biological_process
# 1	GO:0070141	response to UV-A	biological_process
# 1	GO:0080110	sporopollenin biosynthetic process	biological_process
# 1	GO:0030176	N/A	N/A
# 1	GO:0004252	serine-type endopeptidase activity	molecular_function
# 1	GO:1990381	ubiquitin-specific protease binding	molecular_function
# 1	GO:0007283	spermatogenesis	biological_process
# 1	GO:0030154	cell differentiation	biological_process
# 1	GO:0030433	ubiquitin-dependent ERAD pathway	biological_process
# 1	GO:0030968	endoplasmic reticulum unfolded protein response	biological_process
# 1	GO:0033619	membrane protein proteolysis	biological_process
# 1	GO:0051247	positive regulation of protein metabolic process	biological_process
# 1	GO:0016887	ATP hydrolysis activity	molecular_function
# 1	GO:0032570	response to progesterone	biological_process
# 1	GO:0061738	late endosomal microautophagy	biological_process
# 1	GO:0001786	phosphatidylserine binding	molecular_function
# 1	GO:0003723	RNA binding	molecular_function
# 1	GO:0045892	negative regulation of DNA-templated transcription	biological_process
# 1	GO:0001822	kidney development	biological_process
# 1	GO:0051087	protein-folding chaperone binding	molecular_function
# 1	GO:0034620	cellular response to unfolded protein	biological_process
# 1	GO:0031072	heat shock protein binding	molecular_function
# 1	GO:0044849	estrous cycle	biological_process
# 1	GO:0021549	cerebellum development	biological_process
# 1	GO:0031625	ubiquitin protein ligase binding	molecular_function
# 1	GO:0043085	positive regulation of catalytic activity	biological_process
# 1	GO:0006606	protein import into nucleus	biological_process
# 1	GO:0010667	negative regulation of cardiac muscle cell apoptotic process	biological_process
# 1	GO:1904593	prostaglandin binding	molecular_function
# 1	GO:1904592	positive regulation of protein refolding	biological_process
# 1	GO:0042277	peptide binding	molecular_function
# 1	GO:0009410	response to xenobiotic stimulus	biological_process
# 1	GO:0061635	regulation of protein complex stability	biological_process
# 1	GO:0016191	synaptic vesicle uncoating	biological_process
# 1	GO:0034605	cellular response to heat	biological_process
# 1	GO:0048026	positive regulation of mRNA splicing, via spliceosome	biological_process
# 1	GO:0071276	cellular response to cadmium ion	biological_process
# 1	GO:0061740	protein targeting to lysosome involved in chaperone-mediated autophagy	biological_process
# 1	GO:1904764	chaperone-mediated autophagy translocation complex disassembly	biological_process
# 1	GO:0043254	regulation of protein-containing complex assembly	biological_process
# 1	GO:0043531	ADP binding	molecular_function
# 1	GO:0044743	protein transmembrane import into intracellular organelle	biological_process
# 1	GO:0071383	cellular response to steroid hormone stimulus	biological_process
# 1	GO:0007519	skeletal muscle tissue development	biological_process
# 1	GO:1990832	slow axonal transport	biological_process
# 1	GO:1990833	clathrin-uncoating ATPase activity	molecular_function
# 1	GO:1990834	response to odorant	biological_process
# 1	GO:0031686	A1 adenosine receptor binding	molecular_function
# 1	GO:0055131	C3HC4-type RING finger domain binding	molecular_function
# 1	GO:1903206	N/A	N/A
# 1	GO:0030900	forebrain development	biological_process
# 1	GO:1902904	negative regulation of supramolecular fiber organization	biological_process
# 1	GO:0007608	sensory perception of smell	biological_process
# 1	GO:0051726	regulation of cell cycle	biological_process
# 1	GO:0097214	positive regulation of lysosomal membrane permeability	biological_process
# 1	GO:0046034	ATP metabolic process	biological_process
# 1	GO:0032355	response to estradiol	biological_process
# 1	GO:0001916	positive regulation of T cell mediated cytotoxicity	biological_process
# 1	GO:0014823	response to activity	biological_process
# 1	GO:0140545	ATP-dependent protein disaggregase activity	molecular_function
# 1	GO:0050766	positive regulation of phagocytosis	biological_process
# 1	GO:0042594	response to starvation	biological_process
# 1	GO:0002020	protease binding	molecular_function
# 1	GO:0045862	positive regulation of proteolysis	biological_process
# 1	GO:0009615	response to virus	biological_process
# 1	GO:0098880	maintenance of postsynaptic specialization structure	biological_process
# 1	GO:0099175	regulation of postsynapse organization	biological_process
# 1	GO:0005524	ATP binding	molecular_function
# 1	GO:0045471	response to ethanol	biological_process
# 1	GO:0000082	G1/S transition of mitotic cell cycle	biological_process
# 1	GO:0044829	positive regulation by host of viral genome replication	biological_process
# 1	GO:0051085	chaperone cofactor-dependent protein refolding	biological_process
# 1	GO:0051082	unfolded protein binding	molecular_function
# 1	GO:0007568	N/A	N/A
# 1	GO:0009617	response to bacterium	biological_process
# 1	GO:0031647	regulation of protein stability	biological_process
# 1	GO:0030674	protein-macromolecule adaptor activity	molecular_function
# 1	GO:0010045	response to nickel cation	biological_process
# 1	GO:0016413	O-acetyltransferase activity	molecular_function
# 1	GO:0008312	7S RNA binding	molecular_function
# 1	GO:0043022	ribosome binding	molecular_function
# 1	GO:0006617	SRP-dependent cotranslational protein targeting to membrane, signal sequence recognition	biological_process
# 1	GO:0004222	metalloendopeptidase activity	molecular_function
# 1	GO:0046872	metal ion binding	molecular_function
# 1	GO:0006508	proteolysis	biological_process
# 1	GO:0006518	peptide metabolic process	biological_process
# 1	GO:0050794	regulation of cellular process	biological_process
# 1	GO:0015095	magnesium ion transmembrane transporter activity	molecular_function
# 1	GO:0015693	magnesium ion transport	biological_process
# 1	GO:0003729	mRNA binding	molecular_function
# 1	GO:0000146	microfilament motor activity	molecular_function
# 1	GO:0005547	phosphatidylinositol-3,4,5-trisphosphate binding	molecular_function
# 1	GO:0032027	myosin light chain binding	molecular_function
# 1	GO:0006897	endocytosis	biological_process
# 1	GO:0030036	actin cytoskeleton organization	biological_process
# 1	GO:0030048	actin filament-based movement	biological_process
# 1	GO:0043327	chemotaxis to cAMP	biological_process
# 1	GO:0046907	intracellular transport	biological_process
# 1	GO:0065008	regulation of biological quality	biological_process
# 1	GO:0120036	plasma membrane bounded cell projection organization	biological_process
# count	GO ID	GO Term	namespace
# 2	GO:0000166	nucleotide binding	molecular_function
# 2	GO:0051787	misfolded protein binding	molecular_function
# 2	GO:0051015	actin filament binding	molecular_function
# 1	GO:0008061	chitin binding	molecular_function
# 1	GO:0015026	coreceptor activity	molecular_function
# 1	GO:0042803	protein homodimerization activity	molecular_function
# 1	GO:2001080	chitosan binding	molecular_function
# 1	GO:0004674	protein serine/threonine kinase activity	molecular_function
# 1	GO:0004842	ubiquitin-protein transferase activity	molecular_function
# 1	GO:0019199	transmembrane receptor protein kinase activity	molecular_function
# 1	GO:0010942	N/A	N/A
# 1	GO:0005515	protein binding	molecular_function
# 1	GO:0016210	naringenin-chalcone synthase activity	molecular_function
# 1	GO:0090439	tetraketide alpha-pyrone synthase activity	molecular_function
# 1	GO:0030176	N/A	N/A
# 1	GO:0004252	serine-type endopeptidase activity	molecular_function
# 1	GO:1990381	ubiquitin-specific protease binding	molecular_function
# 1	GO:0016887	ATP hydrolysis activity	molecular_function
# 1	GO:0001786	phosphatidylserine binding	molecular_function
# 1	GO:0003723	RNA binding	molecular_function
# 1	GO:0051087	protein-folding chaperone binding	molecular_function
# 1	GO:0031072	heat shock protein binding	molecular_function
# 1	GO:0031625	ubiquitin protein ligase binding	molecular_function
# 1	GO:1904593	prostaglandin binding	molecular_function
# 1	GO:0042277	peptide binding	molecular_function
# 1	GO:0043531	ADP binding	molecular_function
# 1	GO:1990833	clathrin-uncoating ATPase activity	molecular_function
# 1	GO:0031686	A1 adenosine receptor binding	molecular_function
# 1	GO:0055131	C3HC4-type RING finger domain binding	molecular_function
# 1	GO:1903206	N/A	N/A
# 1	GO:0140545	ATP-dependent protein disaggregase activity	molecular_function
# 1	GO:0002020	protease binding	molecular_function
# 1	GO:0005524	ATP binding	molecular_function
# 1	GO:0051082	unfolded protein binding	molecular_function
# 1	GO:0007568	N/A	N/A
# 1	GO:0030674	protein-macromolecule adaptor activity	molecular_function
# 1	GO:0016413	O-acetyltransferase activity	molecular_function
# 1	GO:0008312	7S RNA binding	molecular_function
# 1	GO:0043022	ribosome binding	molecular_function
# 1	GO:0004222	metalloendopeptidase activity	molecular_function
# 1	GO:0046872	metal ion binding	molecular_function
# 1	GO:0015095	magnesium ion transmembrane transporter activity	molecular_function
# 1	GO:0003729	mRNA binding	molecular_function
# 1	GO:0000146	microfilament motor activity	molecular_function
# 1	GO:0005547	phosphatidylinositol-3,4,5-trisphosphate binding	molecular_function
# 1	GO:0032027	myosin light chain binding	molecular_function
# count	GO ID	GO Term	namespace
# 2	GO:0005886	plasma membrane	cellular_component
# 2	GO:0005783	endoplasmic reticulum	cellular_component
# 2	GO:0005730	nucleolus	cellular_component
# 2	GO:0016020	membrane	cellular_component
# 2	GO:0005829	cytosol	cellular_component
# 1	GO:0010942	N/A	N/A
# 1	GO:0016021	membrane	cellular_component
# 1	GO:0000839	Hrd1p ubiquitin ligase ERAD-L complex	cellular_component
# 1	GO:0030176	N/A	N/A
# 1	GO:0014069	postsynaptic density	cellular_component
# 1	GO:0000974	Prp19 complex	cellular_component
# 1	GO:0005874	microtubule	cellular_component
# 1	GO:1990124	messenger ribonucleoprotein complex	cellular_component
# 1	GO:0043195	terminal bouton	cellular_component
# 1	GO:0043198	dendritic shaft	cellular_component
# 1	GO:0043197	dendritic spine	cellular_component
# 1	GO:0098978	glutamatergic synapse	cellular_component
# 1	GO:0061202	clathrin-sculpted gamma-aminobutyric acid transport vesicle membrane	cellular_component
# 1	GO:0005882	intermediate filament	cellular_component
# 1	GO:0005765	lysosomal membrane	cellular_component
# 1	GO:0031906	late endosome lumen	cellular_component
# 1	GO:0016363	nuclear matrix	cellular_component
# 1	GO:0070062	extracellular exosome	cellular_component
# 1	GO:0099523	presynaptic cytosol	cellular_component
# 1	GO:0099524	postsynaptic cytosol	cellular_component
# 1	GO:0098690	glycinergic synapse	cellular_component
# 1	GO:0098684	photoreceptor ribbon synapse	cellular_component
# 1	GO:0031969	chloroplast membrane	cellular_component
# 1	GO:1990836	lysosomal matrix	cellular_component
# 1	GO:1990718	axonemal central pair projection	cellular_component
# 1	GO:0008021	synaptic vesicle	cellular_component
# 1	GO:1903206	N/A	N/A
# 1	GO:0030864	cortical actin cytoskeleton	cellular_component
# 1	GO:0005681	spliceosomal complex	cellular_component
# 1	GO:0042470	melanosome	cellular_component
# 1	GO:0099634	postsynaptic specialization membrane	cellular_component
# 1	GO:0001917	photoreceptor inner segment	cellular_component
# 1	GO:0043204	perikaryon	cellular_component
# 1	GO:0005776	autophagosome	cellular_component
# 1	GO:0007568	N/A	N/A
# 1	GO:0009986	cell surface	cellular_component
# 1	GO:0048471	perinuclear region of cytoplasm	cellular_component
# 1	GO:0045121	membrane raft	cellular_component
# 1	GO:0101031	protein folding chaperone complex	cellular_component
# 1	GO:0005794	Golgi apparatus	cellular_component
# 1	GO:0005786	signal recognition particle, endoplasmic reticulum targeting	cellular_component
# 1	GO:0016604	nuclear body	cellular_component
# 1	GO:0005739	mitochondrion	cellular_component
# 1	GO:0009507	chloroplast	cellular_component
# 1	GO:0005737	cytoplasm	cellular_component
# 1	GO:0005911	cell-cell junction	cellular_component
# 1	GO:0045160	myosin I complex	cellular_component
# 1	GO:0045335	phagocytic vesicle	cellular_component
# 1	GO:0061851	leading edge of lamellipodium	cellular_component
# 1	GO:0070687	macropinocytic cup cytoskeleton	cellular_component
# 1	GO:0098858	actin-based cell projection	cellular_component

# %%
with open("./lasso_models/10xKfold_lasso_output/rutin_nXcv.json", 'r') as file:
    rutin_nXcv = json.load(file)
#rutin_nXcv_matched, rutin_goids, rutin_term_count, rutin_goea = matchgff2(rutin_nXcv['common_features'], goea=True)
rutin_nXcv_matched, rut_goids_biop, rut_term_count_biop, rut_goea_biop = matchgff2(rutin_nXcv['common_features'], namespace=['biological_process', 'molecular_function'], depth_threshold=2, goea=True)
rutin_nXcv_matched, rut_goids_molf, rut_term_count_molf, rut_goea_molf = matchgff2(rutin_nXcv['common_features'], namespace=['molecular_function'], depth_threshold=2, goea=True)
rutin_nXcv_matched, rut_goids_cellc, rut_term_count_cellc, rut_goea_cellc = matchgff2(rutin_nXcv['common_features'], namespace=['cellular_component'], depth_threshold=2, goea=True)
# Out:
# /home/t44p/PW_rawdata/go_obo/go.obo: fmt(1.2) rel(2023-11-15) 46,228 Terms
# GO Enrichment Analysis >>
#
# Load  Ontology Enrichment Analysis ...
#   0%    961 of 946,182 population items found in association
#
# Runing  Ontology Analysis: current study set of 31 IDs.
# 100%     31 of     31 study items found in association
# 100%     31 of     31 study items found in population(946182)
# Calculating 223 uncorrected p-values using fisher_scipy_stats
#      223 terms are associated with     25 of 946,182 population items
#      223 terms are associated with     25 of     31 study items
#   METHOD fdr_bh:
#      223 GO terms found significant (< 0.05=alpha) (223 enriched +   0 purified): statsmodels fdr_bh
#       25 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
# /home/t44p/PW_rawdata/go_obo/go.obo: fmt(1.2) rel(2023-11-15) 46,228 Terms
# GO Enrichment Analysis >>
#
# Load  Ontology Enrichment Analysis ...
#   0%    961 of 946,182 population items found in association
#
# Runing  Ontology Analysis: current study set of 31 IDs.
# 100%     31 of     31 study items found in association
# 100%     31 of     31 study items found in population(946182)
# Calculating 223 uncorrected p-values using fisher_scipy_stats
#      223 terms are associated with     25 of 946,182 population items
#      223 terms are associated with     25 of     31 study items
#   METHOD fdr_bh:
#      223 GO terms found significant (< 0.05=alpha) (223 enriched +   0 purified): statsmodels fdr_bh
#       25 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
# /home/t44p/PW_rawdata/go_obo/go.obo: fmt(1.2) rel(2023-11-15) 46,228 Terms
# GO Enrichment Analysis >>
#
# Load  Ontology Enrichment Analysis ...
#   0%    961 of 946,182 population items found in association
#
# Runing  Ontology Analysis: current study set of 31 IDs.
# 100%     31 of     31 study items found in association
# 100%     31 of     31 study items found in population(946182)
# Calculating 223 uncorrected p-values using fisher_scipy_stats
#      223 terms are associated with     25 of 946,182 population items
#      223 terms are associated with     25 of     31 study items
#   METHOD fdr_bh:
#      223 GO terms found significant (< 0.05=alpha) (223 enriched +   0 purified): statsmodels fdr_bh
#       25 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)

# %%
#plot_go_terms(rutin_term_count, top_n=10)
print("# <<< RUTIN >>>")
print(f"# 10x3FoldCV mean score: {np.mean(rutin_nXcv['mean_scores'])} \n# count common features: {len(rutin_nXcv['common_features'])}")
tabulate(rut_term_count_biop)
tabulate(rut_term_count_molf)
tabulate(rut_term_count_cellc)
# Out:
# # <<< RUTIN >>>
# # 10x3FoldCV mean score: 0.7485866213502098
# # count common features: 31
# count	GO ID	GO Term	namespace
# 6	GO:0005515	protein binding	molecular_function
# 4	GO:0042803	protein homodimerization activity	molecular_function
# 4	GO:0009733	response to auxin	biological_process
# 3	GO:0045892	negative regulation of DNA-templated transcription	biological_process
# 3	GO:0009414	response to water deprivation	biological_process
# 3	GO:0003700	DNA-binding transcription factor activity	molecular_function
# 3	GO:0045893	positive regulation of DNA-templated transcription	biological_process
# 3	GO:0009862	systemic acquired resistance, salicylic acid mediated signaling pathway	biological_process
# 2	GO:0003729	mRNA binding	molecular_function
# 2	GO:0048481	plant ovule development	biological_process
# 2	GO:0006096	glycolytic process	biological_process
# 2	GO:0009734	auxin-activated signaling pathway	biological_process
# 2	GO:0042542	response to hydrogen peroxide	biological_process
# 2	GO:0009723	response to ethylene	biological_process
# 2	GO:0000987	cis-regulatory region sequence-specific DNA binding	molecular_function
# 2	GO:0009753	response to jasmonic acid	biological_process
# 2	GO:0009410	response to xenobiotic stimulus	biological_process
# 2	GO:1905623	positive regulation of leaf development	biological_process
# 2	GO:0042742	defense response to bacterium	biological_process
# 2	GO:0002237	response to molecule of bacterial origin	biological_process
# 2	GO:0009909	regulation of flower development	biological_process
# 2	GO:0048653	anther development	biological_process
# 2	GO:0071588	hydrogen peroxide mediated signaling pathway	biological_process
# 1	GO:0010496	intercellular transport	biological_process
# 1	GO:0046907	intracellular transport	biological_process
# 1	GO:0004842	ubiquitin-protein transferase activity	molecular_function
# 1	GO:0000956	nuclear-transcribed mRNA catabolic process	biological_process
# 1	GO:0010556	regulation of macromolecule biosynthetic process	biological_process
# 1	GO:0016567	protein ubiquitination	biological_process
# 1	GO:0031326	regulation of cellular biosynthetic process	biological_process
# 1	GO:0051254	positive regulation of RNA metabolic process	biological_process
# 1	GO:0003735	structural constituent of ribosome	molecular_function
# 1	GO:0019843	rRNA binding	molecular_function
# 1	GO:0030599	pectinesterase activity	molecular_function
# 1	GO:0045330	aspartyl esterase activity	molecular_function
# 1	GO:0000462	maturation of SSU-rRNA from tricistronic rRNA transcript (SSU-rRNA, 5.8S rRNA, LSU-rRNA)	biological_process
# 1	GO:0002181	cytoplasmic translation	biological_process
# 1	GO:0042545	cell wall modification	biological_process
# 1	GO:0045490	pectin catabolic process	biological_process
# 1	GO:0016757	glycosyltransferase activity	molecular_function
# 1	GO:0008460	dTDP-glucose 4,6-dehydratase activity	molecular_function
# 1	GO:0048040	UDP-glucuronate decarboxylase activity	molecular_function
# 1	GO:0070403	NAD+ binding	molecular_function
# 1	GO:0001503	ossification	biological_process
# 1	GO:0015012	heparan sulfate proteoglycan biosynthetic process	biological_process
# 1	GO:0019305	dTDP-rhamnose biosynthetic process	biological_process
# 1	GO:0030198	extracellular matrix organization	biological_process
# 1	GO:0030206	chondroitin sulfate biosynthetic process	biological_process
# 1	GO:0033320	UDP-D-xylose biosynthetic process	biological_process
# 1	GO:0042732	D-xylose metabolic process	biological_process
# 1	GO:0045492	xylan biosynthetic process	biological_process
# 1	GO:0051216	cartilage development	biological_process
# 1	GO:0070979	protein K11-linked ubiquitination	biological_process
# 1	GO:0009793	embryo development ending in seed dormancy	biological_process
# 1	GO:0031145	anaphase-promoting complex-dependent catabolic process	biological_process
# 1	GO:0045842	positive regulation of mitotic metaphase/anaphase transition	biological_process
# 1	GO:0016709	oxidoreductase activity, acting on paired donors, with incorporation or reduction of molecular oxygen, NAD(P)H as one donor, and incorporation of one atom of oxygen	molecular_function
# 1	GO:0046872	metal ion binding	molecular_function
# 1	GO:0009813	flavonoid biosynthetic process	biological_process
# 1	GO:0004742	dihydrolipoyllysine-residue acetyltransferase activity	molecular_function
# 1	GO:0006086	acetyl-CoA biosynthetic process from pyruvate	biological_process
# 1	GO:0030431	sleep	biological_process
# 1	GO:0051240	positive regulation of multicellular organismal process	biological_process
# 1	GO:0004332	fructose-bisphosphate aldolase activity	molecular_function
# 1	GO:0043621	protein self-association	molecular_function
# 1	GO:0005986	sucrose biosynthetic process	biological_process
# 1	GO:0006000	fructose metabolic process	biological_process
# 1	GO:0006094	gluconeogenesis	biological_process
# 1	GO:0030388	fructose 1,6-bisphosphate metabolic process	biological_process
# 1	GO:0031930	mitochondria-nucleus signaling pathway	biological_process
# 1	GO:0034059	response to anoxia	biological_process
# 1	GO:0048364	root development	biological_process
# 1	GO:0008964	phosphoenolpyruvate carboxylase activity	molecular_function
# 1	GO:0006099	tricarboxylic acid cycle	biological_process
# 1	GO:0009760	C4 photosynthesis	biological_process
# 1	GO:0009915	phloem sucrose loading	biological_process
# 1	GO:0048366	leaf development	biological_process
# 1	GO:0051262	protein tetramerization	biological_process
# 1	GO:0004144	diacylglycerol O-acyltransferase activity	molecular_function
# 1	GO:0006071	glycerol metabolic process	biological_process
# 1	GO:0019216	regulation of lipid metabolic process	biological_process
# 1	GO:0019432	triglyceride biosynthetic process	biological_process
# 1	GO:0019915	lipid storage	biological_process
# 1	GO:0031323	regulation of cellular metabolic process	biological_process
# 1	GO:0034389	lipid droplet organization	biological_process
# 1	GO:0055088	lipid homeostasis	biological_process
# 1	GO:0062012	regulation of small molecule metabolic process	biological_process
# 1	GO:1900140	regulation of seedling development	biological_process
# 1	GO:1902074	response to salt	biological_process
# 1	GO:0009651	response to salt stress	biological_process
# 1	GO:0090058	metaxylem development	biological_process
# 1	GO:0043068	positive regulation of programmed cell death	biological_process
# 1	GO:0000976	transcription cis-regulatory region binding	molecular_function
# 1	GO:1900057	positive regulation of leaf senescence	biological_process
# 1	GO:0051091	positive regulation of DNA-binding transcription factor activity	biological_process
# 1	GO:1901348	positive regulation of secondary cell wall biogenesis	biological_process
# 1	GO:0009735	response to cytokinin	biological_process
# 1	GO:0048759	xylem vessel member cell differentiation	biological_process
# 1	GO:1903648	positive regulation of chlorophyll catabolic process	biological_process
# 1	GO:1990110	callus formation	biological_process
# 1	GO:0045491	xylan metabolic process	biological_process
# 1	GO:0051782	negative regulation of cell division	biological_process
# 1	GO:2000014	regulation of endosperm development	biological_process
# 1	GO:1904250	positive regulation of age-related resistance	biological_process
# 1	GO:0010199	organ boundary specification between lateral organs and the meristem	biological_process
# 1	GO:0048829	root cap development	biological_process
# 1	GO:0090400	stress-induced premature senescence	biological_process
# 1	GO:0080187	floral organ senescence	biological_process
# 1	GO:0010072	primary shoot apical meristem specification	biological_process
# 1	GO:0009620	response to fungus	biological_process
# 1	GO:0009741	response to brassinosteroid	biological_process
# 1	GO:0048527	lateral root development	biological_process
# 1	GO:0009737	response to abscisic acid	biological_process
# 1	GO:0010628	positive regulation of gene expression	biological_process
# 1	GO:0090709	regulation of timing of plant organ formation	biological_process
# 1	GO:0010029	regulation of seed germination	biological_process
# 1	GO:0010981	regulation of cell wall macromolecule metabolic process	biological_process
# 1	GO:0010223	secondary shoot formation	biological_process
# 1	GO:0004707	MAP kinase activity	molecular_function
# 1	GO:0004712	protein serine/threonine/tyrosine kinase activity	molecular_function
# 1	GO:0004713	protein tyrosine kinase activity	molecular_function
# 1	GO:0005524	ATP binding	molecular_function
# 1	GO:0019902	phosphatase binding	molecular_function
# 1	GO:0106310	protein serine kinase activity	molecular_function
# 1	GO:0000165	MAPK cascade	biological_process
# 1	GO:0002221	pattern recognition receptor signaling pathway	biological_process
# 1	GO:0007049	cell cycle	biological_process
# 1	GO:0009555	pollen development	biological_process
# 1	GO:0009611	response to wounding	biological_process
# 1	GO:0009626	plant-type hypersensitive response	biological_process
# 1	GO:0009738	abscisic acid-activated signaling pathway	biological_process
# 1	GO:0009864	induced systemic resistance, jasmonic acid mediated signaling pathway	biological_process
# 1	GO:0009875	pollen-pistil interaction	biological_process
# 1	GO:0010051	xylem and phloem pattern formation	biological_process
# 1	GO:0010082	regulation of root meristem growth	biological_process
# 1	GO:0010120	camalexin biosynthetic process	biological_process
# 1	GO:0010150	leaf senescence	biological_process
# 1	GO:0010183	pollen tube guidance	biological_process
# 1	GO:0010200	response to chitin	biological_process
# 1	GO:0010224	response to UV-B	biological_process
# 1	GO:0010229	inflorescence development	biological_process
# 1	GO:0010311	lateral root formation	biological_process
# 1	GO:0010468	regulation of gene expression	biological_process
# 1	GO:0018108	peptidyl-tyrosine phosphorylation	biological_process
# 1	GO:0042539	hypotonic salinity response	biological_process
# 1	GO:0043622	cortical microtubule organization	biological_process
# 1	GO:0046777	protein autophosphorylation	biological_process
# 1	GO:0050826	response to freezing	biological_process
# 1	GO:0050832	defense response to fungus	biological_process
# 1	GO:0051301	cell division	biological_process
# 1	GO:0051510	regulation of unidimensional cell growth	biological_process
# 1	GO:0060918	auxin transport	biological_process
# 1	GO:0071244	cellular response to carbon dioxide	biological_process
# 1	GO:0080026	response to indolebutyric acid	biological_process
# 1	GO:0080136	priming of cellular response to stress	biological_process
# 1	GO:0090333	regulation of stomatal closure	biological_process
# 1	GO:1901002	positive regulation of response to salt stress	biological_process
# 1	GO:1902065	response to L-glutamate	biological_process
# 1	GO:0004324	ferredoxin-NADP+ reductase activity	molecular_function
# 1	GO:0015979	photosynthesis	biological_process
# 1	GO:0001046	core promoter sequence-specific DNA binding	molecular_function
# 1	GO:0006355	regulation of DNA-templated transcription	biological_process
# 1	GO:0010118	stomatal movement	biological_process
# 1	GO:0010167	response to nitrate	biological_process
# 1	GO:0042128	nitrate assimilation	biological_process
# 1	GO:0003989	acetyl-CoA carboxylase activity	molecular_function
# 1	GO:0006633	fatty acid biosynthetic process	biological_process
# 1	GO:0004851	uroporphyrin-III C-methyltransferase activity	molecular_function
# 1	GO:0009416	response to light stimulus	biological_process
# 1	GO:0019354	siroheme biosynthetic process	biological_process
# 1	GO:0090352	regulation of nitrate assimilation	biological_process
# 1	GO:1900058	regulation of sulfate assimilation	biological_process
# 1	GO:1902326	positive regulation of chlorophyll biosynthetic process	biological_process
# 1	GO:0004252	serine-type endopeptidase activity	molecular_function
# 1	GO:0006508	proteolysis	biological_process
# 1	GO:0009608	response to symbiont	biological_process
# 1	GO:0009682	induced systemic resistance	biological_process
# 1	GO:0009860	pollen tube growth	biological_process
# count	GO ID	GO Term	namespace
# 6	GO:0005515	protein binding	molecular_function
# 4	GO:0042803	protein homodimerization activity	molecular_function
# 3	GO:0003700	DNA-binding transcription factor activity	molecular_function
# 2	GO:0003729	mRNA binding	molecular_function
# 2	GO:0000987	cis-regulatory region sequence-specific DNA binding	molecular_function
# 1	GO:0004842	ubiquitin-protein transferase activity	molecular_function
# 1	GO:0003735	structural constituent of ribosome	molecular_function
# 1	GO:0019843	rRNA binding	molecular_function
# 1	GO:0030599	pectinesterase activity	molecular_function
# 1	GO:0045330	aspartyl esterase activity	molecular_function
# 1	GO:0016757	glycosyltransferase activity	molecular_function
# 1	GO:0008460	dTDP-glucose 4,6-dehydratase activity	molecular_function
# 1	GO:0048040	UDP-glucuronate decarboxylase activity	molecular_function
# 1	GO:0070403	NAD+ binding	molecular_function
# 1	GO:0016709	oxidoreductase activity, acting on paired donors, with incorporation or reduction of molecular oxygen, NAD(P)H as one donor, and incorporation of one atom of oxygen	molecular_function
# 1	GO:0046872	metal ion binding	molecular_function
# 1	GO:0004742	dihydrolipoyllysine-residue acetyltransferase activity	molecular_function
# 1	GO:0004332	fructose-bisphosphate aldolase activity	molecular_function
# 1	GO:0043621	protein self-association	molecular_function
# 1	GO:0008964	phosphoenolpyruvate carboxylase activity	molecular_function
# 1	GO:0004144	diacylglycerol O-acyltransferase activity	molecular_function
# 1	GO:0000976	transcription cis-regulatory region binding	molecular_function
# 1	GO:0004707	MAP kinase activity	molecular_function
# 1	GO:0004712	protein serine/threonine/tyrosine kinase activity	molecular_function
# 1	GO:0004713	protein tyrosine kinase activity	molecular_function
# 1	GO:0005524	ATP binding	molecular_function
# 1	GO:0019902	phosphatase binding	molecular_function
# 1	GO:0106310	protein serine kinase activity	molecular_function
# 1	GO:0004324	ferredoxin-NADP+ reductase activity	molecular_function
# 1	GO:0001046	core promoter sequence-specific DNA binding	molecular_function
# 1	GO:0003989	acetyl-CoA carboxylase activity	molecular_function
# 1	GO:0004851	uroporphyrin-III C-methyltransferase activity	molecular_function
# 1	GO:0004252	serine-type endopeptidase activity	molecular_function
# count	GO ID	GO Term	namespace
# 4	GO:0005634	nucleus	cellular_component
# 3	GO:0005783	endoplasmic reticulum	cellular_component
# 3	GO:0016021	membrane	cellular_component
# 3	GO:0016020	membrane	cellular_component
# 3	GO:0005737	cytoplasm	cellular_component
# 3	GO:0009507	chloroplast	cellular_component
# 2	GO:0005576	extracellular region	cellular_component
# 2	GO:0005829	cytosol	cellular_component
# 2	GO:0005886	plasma membrane	cellular_component
# 2	GO:0090575	RNA polymerase II transcription regulator complex	cellular_component
# 2	GO:0090571	RNA polymerase II transcription repressor complex	cellular_component
# 1	GO:0009506	plasmodesma	cellular_component
# 1	GO:0005622	intracellular anatomical structure	cellular_component
# 1	GO:0030014	CCR4-NOT complex	cellular_component
# 1	GO:0000228	nuclear chromosome	cellular_component
# 1	GO:0005730	nucleolus	cellular_component
# 1	GO:0022627	cytosolic small ribosomal subunit	cellular_component
# 1	GO:0032580	Golgi cisterna membrane	cellular_component
# 1	GO:1902494	catalytic complex	cellular_component
# 1	GO:0005680	anaphase-promoting complex	cellular_component
# 1	GO:0034399	nuclear periphery	cellular_component
# 1	GO:0005759	mitochondrial matrix	cellular_component
# 1	GO:0009570	chloroplast stroma	cellular_component
# 1	GO:0045254	pyruvate dehydrogenase complex	cellular_component
# 1	GO:0098798	mitochondrial protein-containing complex	cellular_component
# 1	GO:0120025	plasma membrane bounded cell projection	cellular_component
# 1	GO:0005739	mitochondrion	cellular_component
# 1	GO:0010287	plastoglobule	cellular_component
# 1	GO:0005794	Golgi apparatus	cellular_component
# 1	GO:0005789	endoplasmic reticulum membrane	cellular_component
# 1	GO:0005811	lipid droplet	cellular_component
# 1	GO:0097038	perinuclear endoplasmic reticulum	cellular_component
# 1	GO:0009531	secondary cell wall	cellular_component
# 1	GO:0005802	trans-Golgi network	cellular_component
# 1	GO:0005938	cell cortex	cellular_component
# 1	GO:0009524	phragmoplast	cellular_component
# 1	GO:0009574	preprophase band	cellular_component
# 1	GO:0009579	thylakoid	cellular_component
# 1	GO:0005618	cell wall	cellular_component
# 1	GO:0031012	extracellular matrix	cellular_component

# %%
with open("./lasso_models/10xKfold_lasso_output/trehalose_nXcv.json", 'r') as file:
    trehalose_nXcv = json.load(file)
#trehalose_nXcv_matched, trehalose_goids, trehalose_term_count, trehalose_goea = matchgff2(trehalose_nXcv['common_features'], goea=True)
trehalose_nXcv_matched, tre_goids_biop, tre_term_count_biop, tre_goea_biop = matchgff2(trehalose_nXcv['common_features'], namespace=['biological_process', 'molecular_function'], depth_threshold=2, goea=True)
trehalose_nXcv_matched, tre_goids_molf, tre_term_count_molf, tre_goea_molf = matchgff2(trehalose_nXcv['common_features'], namespace=['molecular_function'], depth_threshold=2, goea=True)
trehalose_nXcv_matched, tre_goids_cellc, tre_term_count_cellc, tre_goea_cellc = matchgff2(trehalose_nXcv['common_features'], namespace=['cellular_component'], depth_threshold=2, goea=True)
# Out:
# /home/t44p/PW_rawdata/go_obo/go.obo: fmt(1.2) rel(2023-11-15) 46,228 Terms
# GO Enrichment Analysis >>
#
# Load  Ontology Enrichment Analysis ...
#   0%    196 of 427,308 population items found in association
#
# Runing  Ontology Analysis: current study set of 14 IDs.
# 100%     14 of     14 study items found in association
# 100%     14 of     14 study items found in population(427308)
# Calculating 139 uncorrected p-values using fisher_scipy_stats
#      139 terms are associated with     10 of 427,308 population items
#      139 terms are associated with     10 of     14 study items
#   METHOD fdr_bh:
#      139 GO terms found significant (< 0.05=alpha) (139 enriched +   0 purified): statsmodels fdr_bh
#       10 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
# /home/t44p/PW_rawdata/go_obo/go.obo: fmt(1.2) rel(2023-11-15) 46,228 Terms
# GO Enrichment Analysis >>
#
# Load  Ontology Enrichment Analysis ...
#   0%    196 of 427,308 population items found in association
#
# Runing  Ontology Analysis: current study set of 14 IDs.
# 100%     14 of     14 study items found in association
# 100%     14 of     14 study items found in population(427308)
# Calculating 139 uncorrected p-values using fisher_scipy_stats
#      139 terms are associated with     10 of 427,308 population items
#      139 terms are associated with     10 of     14 study items
#   METHOD fdr_bh:
#      139 GO terms found significant (< 0.05=alpha) (139 enriched +   0 purified): statsmodels fdr_bh
#       10 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
# /home/t44p/PW_rawdata/go_obo/go.obo: fmt(1.2) rel(2023-11-15) 46,228 Terms
# GO Enrichment Analysis >>
#
# Load  Ontology Enrichment Analysis ...
#   0%    196 of 427,308 population items found in association
#
# Runing  Ontology Analysis: current study set of 14 IDs.
# 100%     14 of     14 study items found in association
# 100%     14 of     14 study items found in population(427308)
# Calculating 139 uncorrected p-values using fisher_scipy_stats
#      139 terms are associated with     10 of 427,308 population items
#      139 terms are associated with     10 of     14 study items
#   METHOD fdr_bh:
#      139 GO terms found significant (< 0.05=alpha) (139 enriched +   0 purified): statsmodels fdr_bh
#       10 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)

# %%
#plot_go_terms(trehalose_term_count, top_n=10)
print("# <<< TREHALOSE >>>")
print(f"# 10x3FoldCV mean score: {np.mean(trehalose_nXcv['mean_scores'])} \n# count common features: {len(trehalose_nXcv['common_features'])}")

tabulate(tre_term_count_biop)
tabulate(tre_term_count_molf)
tabulate(tre_term_count_cellc)
# Out:
# # <<< TREHALOSE >>>
# # 10x3FoldCV mean score: 0.7162380753151226
# # count common features: 14
# count	GO ID	GO Term	namespace
# 3	GO:0005515	protein binding	molecular_function
# 2	GO:0042127	regulation of cell population proliferation	biological_process
# 1	GO:0006807	nitrogen compound metabolic process	biological_process
# 1	GO:0006974	DNA damage response	biological_process
# 1	GO:0043170	macromolecule metabolic process	biological_process
# 1	GO:0044238	primary metabolic process	biological_process
# 1	GO:0050794	regulation of cellular process	biological_process
# 1	GO:0003676	nucleic acid binding	molecular_function
# 1	GO:0034051	negative regulation of plant-type hypersensitive response	biological_process
# 1	GO:0050832	defense response to fungus	biological_process
# 1	GO:0061057	peptidoglycan recognition protein signaling pathway	biological_process
# 1	GO:0061630	ubiquitin protein ligase activity	molecular_function
# 1	GO:0070628	proteasome binding	molecular_function
# 1	GO:0061631	ubiquitin conjugating enzyme activity	molecular_function
# 1	GO:0016925	protein sumoylation	biological_process
# 1	GO:0044314	protein K27-linked ubiquitination	biological_process
# 1	GO:0000278	mitotic cell cycle	biological_process
# 1	GO:0005524	ATP binding	molecular_function
# 1	GO:0043130	ubiquitin binding	molecular_function
# 1	GO:0072344	rescue of stalled ribosome	biological_process
# 1	GO:0035519	protein K29-linked ubiquitination	biological_process
# 1	GO:0051865	protein autoubiquitination	biological_process
# 1	GO:0070979	protein K11-linked ubiquitination	biological_process
# 1	GO:0070936	protein K48-linked ubiquitination	biological_process
# 1	GO:0071629	cytoplasm protein quality control by the ubiquitin-proteasome system	biological_process
# 1	GO:0007140	male meiotic nuclear division	biological_process
# 1	GO:0045676	regulation of R7 cell differentiation	biological_process
# 1	GO:0009960	endosperm development	biological_process
# 1	GO:0006513	protein monoubiquitination	biological_process
# 1	GO:0045879	negative regulation of smoothened signaling pathway	biological_process
# 1	GO:0072671	mitochondria-associated ubiquitin-dependent protein catabolic process	biological_process
# 1	GO:0048132	female germ-line stem cell asymmetric division	biological_process
# 1	GO:0032933	SREBP signaling pathway	biological_process
# 1	GO:0031625	ubiquitin protein ligase binding	molecular_function
# 1	GO:0031647	regulation of protein stability	biological_process
# 1	GO:1990116	ribosome-associated ubiquitin-dependent protein catabolic process	biological_process
# 1	GO:0051276	chromosome organization	biological_process
# 1	GO:0043162	ubiquitin-dependent protein catabolic process via the multivesicular body sorting pathway	biological_process
# 1	GO:0030718	germ-line stem cell population maintenance	biological_process
# 1	GO:0097039	protein linear polyubiquitination	biological_process
# 1	GO:0031145	anaphase-promoting complex-dependent catabolic process	biological_process
# 1	GO:0070534	protein K63-linked ubiquitination	biological_process
# 1	GO:0010623	programmed cell death involved in cell development	biological_process
# 1	GO:0016322	neuron remodeling	biological_process
# 1	GO:0085020	protein K6-linked ubiquitination	biological_process
# 1	GO:0030674	protein-macromolecule adaptor activity	molecular_function
# 1	GO:0005315	inorganic phosphate transmembrane transporter activity	molecular_function
# 1	GO:0015114	phosphate ion transmembrane transporter activity	molecular_function
# 1	GO:0015293	symporter activity	molecular_function
# 1	GO:1901683	arsenate ion transmembrane transporter activity	molecular_function
# 1	GO:0009610	response to symbiotic fungus	biological_process
# 1	GO:0009873	ethylene-activated signaling pathway	biological_process
# 1	GO:0016036	cellular response to phosphate starvation	biological_process
# 1	GO:0035435	phosphate ion transmembrane transport	biological_process
# 1	GO:0080187	floral organ senescence	biological_process
# 1	GO:1901684	arsenate ion transmembrane transport	biological_process
# 1	GO:0000978	RNA polymerase II cis-regulatory region sequence-specific DNA binding	molecular_function
# 1	GO:0048767	root hair elongation	biological_process
# 1	GO:0046983	protein dimerization activity	molecular_function
# 1	GO:0048446	petal morphogenesis	biological_process
# 1	GO:0009637	response to blue light	biological_process
# 1	GO:0009911	positive regulation of flower development	biological_process
# 1	GO:0045824	negative regulation of innate immune response	biological_process
# 1	GO:1902448	positive regulation of shade avoidance	biological_process
# 1	GO:0000981	DNA-binding transcription factor activity, RNA polymerase II-specific	molecular_function
# 1	GO:0006357	regulation of transcription by RNA polymerase II	biological_process
# 1	GO:0009739	response to gibberellin	biological_process
# 1	GO:0048235	pollen sperm cell differentiation	biological_process
# 1	GO:2000488	positive regulation of brassinosteroid biosynthetic process	biological_process
# 1	GO:0071368	cellular response to cytokinin stimulus	biological_process
# 1	GO:2000762	regulation of phenylpropanoid metabolic process	biological_process
# 1	GO:0008198	ferrous iron binding	molecular_function
# 1	GO:0008270	zinc ion binding	molecular_function
# 1	GO:0046566	DOPA dioxygenase activity	molecular_function
# 1	GO:0050297	stizolobate synthase activity	molecular_function
# 1	GO:0006725	cellular aromatic compound metabolic process	biological_process
# 1	GO:0046148	pigment biosynthetic process	biological_process
# 1	GO:0001671	ATPase activator activity	molecular_function
# 1	GO:0003677	DNA binding	molecular_function
# 1	GO:0051082	unfolded protein binding	molecular_function
# 1	GO:0051087	protein-folding chaperone binding	molecular_function
# 1	GO:0000122	negative regulation of transcription by RNA polymerase II	biological_process
# 1	GO:0006986	response to unfolded protein	biological_process
# 1	GO:0009408	response to heat	biological_process
# 1	GO:0010322	regulation of isopentenyl diphosphate biosynthetic process, methylerythritol 4-phosphate pathway	biological_process
# 1	GO:0030036	actin cytoskeleton organization	biological_process
# 1	GO:0030198	extracellular matrix organization	biological_process
# 1	GO:0034504	protein localization to nucleus	biological_process
# 1	GO:0042407	cristae formation	biological_process
# 1	GO:0060710	chorio-allantoic fusion	biological_process
# 1	GO:0060715	syncytiotrophoblast cell differentiation involved in labyrinthine layer development	biological_process
# 1	GO:0060717	chorion development	biological_process
# 1	GO:0061077	chaperone-mediated protein folding	biological_process
# 1	GO:1902395	regulation of 1-deoxy-D-xylulose-5-phosphate synthase activity	biological_process
# 1	GO:0010581	regulation of starch biosynthetic process	biological_process
# 1	GO:0080050	regulation of seed development	biological_process
# 1	GO:0060860	regulation of floral organ abscission	biological_process
# 1	GO:0000976	transcription cis-regulatory region binding	molecular_function
# 1	GO:0080037	negative regulation of cytokinin-activated signaling pathway	biological_process
# 1	GO:0040019	positive regulation of embryonic development	biological_process
# 1	GO:1990110	callus formation	biological_process
# 1	GO:0051301	cell division	biological_process
# 1	GO:0009409	response to cold	biological_process
# 1	GO:0003700	DNA-binding transcription factor activity	molecular_function
# 1	GO:0045892	negative regulation of DNA-templated transcription	biological_process
# 1	GO:0009909	regulation of flower development	biological_process
# 1	GO:0019760	glucosinolate metabolic process	biological_process
# 1	GO:2000014	regulation of endosperm development	biological_process
# 1	GO:0097548	seed abscission	biological_process
# 1	GO:0048481	plant ovule development	biological_process
# 1	GO:0010311	lateral root formation	biological_process
# 1	GO:0010492	maintenance of shoot apical meristem identity	biological_process
# 1	GO:0060772	leaf phyllotactic patterning	biological_process
# 1	GO:0010093	specification of floral organ identity	biological_process
# 1	GO:0000723	telomere maintenance	biological_process
# 1	GO:0060774	auxin mediated signaling pathway involved in phyllotactic patterning	biological_process
# 1	GO:0009845	seed germination	biological_process
# 1	GO:0048830	adventitious root development	biological_process
# 1	GO:0010449	root meristem growth	biological_process
# 1	GO:0030154	cell differentiation	biological_process
# 1	GO:0010228	vegetative to reproductive phase transition of meristem	biological_process
# 1	GO:0010601	positive regulation of auxin biosynthetic process	biological_process
# count	GO ID	GO Term	namespace
# 3	GO:0005515	protein binding	molecular_function
# 1	GO:0003676	nucleic acid binding	molecular_function
# 1	GO:0061630	ubiquitin protein ligase activity	molecular_function
# 1	GO:0070628	proteasome binding	molecular_function
# 1	GO:0061631	ubiquitin conjugating enzyme activity	molecular_function
# 1	GO:0005524	ATP binding	molecular_function
# 1	GO:0043130	ubiquitin binding	molecular_function
# 1	GO:0031625	ubiquitin protein ligase binding	molecular_function
# 1	GO:0030674	protein-macromolecule adaptor activity	molecular_function
# 1	GO:0005315	inorganic phosphate transmembrane transporter activity	molecular_function
# 1	GO:0015114	phosphate ion transmembrane transporter activity	molecular_function
# 1	GO:0015293	symporter activity	molecular_function
# 1	GO:1901683	arsenate ion transmembrane transporter activity	molecular_function
# 1	GO:0000978	RNA polymerase II cis-regulatory region sequence-specific DNA binding	molecular_function
# 1	GO:0046983	protein dimerization activity	molecular_function
# 1	GO:0000981	DNA-binding transcription factor activity, RNA polymerase II-specific	molecular_function
# 1	GO:0008198	ferrous iron binding	molecular_function
# 1	GO:0008270	zinc ion binding	molecular_function
# 1	GO:0046566	DOPA dioxygenase activity	molecular_function
# 1	GO:0050297	stizolobate synthase activity	molecular_function
# 1	GO:0001671	ATPase activator activity	molecular_function
# 1	GO:0003677	DNA binding	molecular_function
# 1	GO:0051082	unfolded protein binding	molecular_function
# 1	GO:0051087	protein-folding chaperone binding	molecular_function
# 1	GO:0000976	transcription cis-regulatory region binding	molecular_function
# 1	GO:0003700	DNA-binding transcription factor activity	molecular_function
# count	GO ID	GO Term	namespace
# 3	GO:0005634	nucleus	cellular_component
# 3	GO:0005886	plasma membrane	cellular_component
# 3	GO:0016021	membrane	cellular_component
# 2	GO:0005829	cytosol	cellular_component
# 2	GO:0009507	chloroplast	cellular_component
# 1	GO:0005737	cytoplasm	cellular_component
# 1	GO:0005694	chromosome	cellular_component
# 1	GO:0005654	nucleoplasm	cellular_component
# 1	GO:0000151	ubiquitin ligase complex	cellular_component
# 1	GO:0005794	Golgi apparatus	cellular_component
# 1	GO:0005622	intracellular anatomical structure	cellular_component
# 1	GO:0001401	SAM complex	cellular_component
# 1	GO:0005788	endoplasmic reticulum lumen	cellular_component
# 1	GO:0016607	nuclear speck	cellular_component
# 1	GO:0061617	MICOS complex	cellular_component
# 1	GO:0005667	transcription regulator complex	cellular_component

# %%
with open("./lasso_models/10xKfold_lasso_output/oxGlut_nXcv.json", 'r') as file:
    oxGlut_nXcv = json.load(file)
#oxGlut_nXcv_matched, oxGlut_goids, oxGlut_term_count, oxGlut_goea = matchgff2(oxGlut_nXcv['common_features'], goea=True)
oxGlut_nXcv_matched, oxGlut_goids_biop, oxGlut_term_count_biop, oxGlut_goea_biop = matchgff2(oxGlut_nXcv['common_features'], namespace=['biological_process', 'molecular_function'], depth_threshold=2, goea=True)
oxGlut_nXcv_matched, oxGlut_goids_molf, oxGlut_term_count_molf, oxGlut_goea_molf = matchgff2(oxGlut_nXcv['common_features'], namespace=['molecular_function'], depth_threshold=2, goea=True)
oxGlut_nXcv_matched, oxGlut_goids_cellc, oxGlut_term_count_cellc, oxGlut_goea_cellc = matchgff2(oxGlut_nXcv['common_features'], namespace=['cellular_component'], depth_threshold=2, goea=True)
# Out:
# /home/t44p/PW_rawdata/go_obo/go.obo: fmt(1.2) rel(2023-11-15) 46,228 Terms
# GO Enrichment Analysis >>
#
# Load  Ontology Enrichment Analysis ...
#   0%  1,024 of 976,704 population items found in association
#
# Runing  Ontology Analysis: current study set of 32 IDs.
# 100%     32 of     32 study items found in association
# 100%     32 of     32 study items found in population(976704)
# Calculating 244 uncorrected p-values using fisher_scipy_stats
#      244 terms are associated with     23 of 976,704 population items
#      244 terms are associated with     23 of     32 study items
#   METHOD fdr_bh:
#      244 GO terms found significant (< 0.05=alpha) (244 enriched +   0 purified): statsmodels fdr_bh
#       23 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
# /home/t44p/PW_rawdata/go_obo/go.obo: fmt(1.2) rel(2023-11-15) 46,228 Terms
# GO Enrichment Analysis >>
#
# Load  Ontology Enrichment Analysis ...
#   0%  1,024 of 976,704 population items found in association
#
# Runing  Ontology Analysis: current study set of 32 IDs.
# 100%     32 of     32 study items found in association
# 100%     32 of     32 study items found in population(976704)
# Calculating 244 uncorrected p-values using fisher_scipy_stats
#      244 terms are associated with     23 of 976,704 population items
#      244 terms are associated with     23 of     32 study items
#   METHOD fdr_bh:
#      244 GO terms found significant (< 0.05=alpha) (244 enriched +   0 purified): statsmodels fdr_bh
#       23 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
# /home/t44p/PW_rawdata/go_obo/go.obo: fmt(1.2) rel(2023-11-15) 46,228 Terms
# GO Enrichment Analysis >>
#
# Load  Ontology Enrichment Analysis ...
#   0%  1,024 of 976,704 population items found in association
#
# Runing  Ontology Analysis: current study set of 32 IDs.
# 100%     32 of     32 study items found in association
# 100%     32 of     32 study items found in population(976704)
# Calculating 244 uncorrected p-values using fisher_scipy_stats
#      244 terms are associated with     23 of 976,704 population items
#      244 terms are associated with     23 of     32 study items
#   METHOD fdr_bh:
#      244 GO terms found significant (< 0.05=alpha) (244 enriched +   0 purified): statsmodels fdr_bh
#       23 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)

# %%
#plot_go_terms(oxGlut_term_count, top_n=10)
print("# <<< OXIDIZED GLUTATHIONE >>>")
print(f"# 10x3FoldCV mean score: {np.mean(oxGlut_nXcv['mean_scores'])} \n# count common features: {len(oxGlut_nXcv['common_features'])}")
tabulate(oxGlut_term_count_biop)
tabulate(oxGlut_term_count_molf)
tabulate(oxGlut_term_count_cellc)
# Out:
# # <<< OXIDIZED GLUTATHIONE >>>
# # 10x3FoldCV mean score: 0.657258809998042
# # count common features: 32
# count	GO ID	GO Term	namespace
# 10	GO:0005515	protein binding	molecular_function
# 4	GO:0009414	response to water deprivation	biological_process
# 3	GO:0000166	nucleotide binding	molecular_function
# 3	GO:0003729	mRNA binding	molecular_function
# 2	GO:0010970	transport along microtubule	biological_process
# 2	GO:0050794	regulation of cellular process	biological_process
# 2	GO:0009409	response to cold	biological_process
# 2	GO:0009651	response to salt stress	biological_process
# 2	GO:0009737	response to abscisic acid	biological_process
# 2	GO:0000978	RNA polymerase II cis-regulatory region sequence-specific DNA binding	molecular_function
# 2	GO:0010228	vegetative to reproductive phase transition of meristem	biological_process
# 2	GO:0016310	phosphorylation	biological_process
# 2	GO:0008270	zinc ion binding	molecular_function
# 2	GO:0031425	chloroplast RNA processing	biological_process
# 2	GO:0080156	mitochondrial mRNA modification	biological_process
# 2	GO:1900865	chloroplast RNA modification	biological_process
# 2	GO:0015031	protein transport	biological_process
# 2	GO:0005524	ATP binding	molecular_function
# 2	GO:0016887	ATP hydrolysis activity	molecular_function
# 1	GO:0008092	cytoskeletal protein binding	molecular_function
# 1	GO:0002009	morphogenesis of an epithelium	biological_process
# 1	GO:0006996	organelle organization	biological_process
# 1	GO:0007368	determination of left/right symmetry	biological_process
# 1	GO:0008104	protein localization	biological_process
# 1	GO:0009860	pollen tube growth	biological_process
# 1	GO:0031347	regulation of defense response	biological_process
# 1	GO:0035295	tube development	biological_process
# 1	GO:0048513	animal organ development	biological_process
# 1	GO:0051656	establishment of organelle localization	biological_process
# 1	GO:0072001	renal system development	biological_process
# 1	GO:0120036	plasma membrane bounded cell projection organization	biological_process
# 1	GO:1903046	meiotic cell cycle process	biological_process
# 1	GO:0000254	C-4 methylsterol oxidase activity	molecular_function
# 1	GO:0005506	iron ion binding	molecular_function
# 1	GO:0009924	octadecanal decarbonylase activity	molecular_function
# 1	GO:1990465	aldehyde oxygenase (deformylating) activity	molecular_function
# 1	GO:0006723	cuticle hydrocarbon biosynthetic process	biological_process
# 1	GO:0010025	wax biosynthetic process	biological_process
# 1	GO:0016126	sterol biosynthetic process	biological_process
# 1	GO:0043447	alkane biosynthetic process	biological_process
# 1	GO:0046184	aldehyde biosynthetic process	biological_process
# 1	GO:0048235	pollen sperm cell differentiation	biological_process
# 1	GO:0048653	anther development	biological_process
# 1	GO:0098542	defense response to other organism	biological_process
# 1	GO:0003713	transcription coactivator activity	molecular_function
# 1	GO:0031490	chromatin DNA binding	molecular_function
# 1	GO:0009751	response to salicylic acid	biological_process
# 1	GO:0045723	positive regulation of fatty acid biosynthetic process	biological_process
# 1	GO:0042659	regulation of cell fate specification	biological_process
# 1	GO:0001228	DNA-binding transcription activator activity, RNA polymerase II-specific	molecular_function
# 1	GO:0008542	visual learning	biological_process
# 1	GO:0060323	head morphogenesis	biological_process
# 1	GO:0009954	proximal/distal pattern formation	biological_process
# 1	GO:0048363	mucilage pectin metabolic process	biological_process
# 1	GO:0110024	positive regulation of cardiac muscle myoblast proliferation	biological_process
# 1	GO:0001742	oenocyte differentiation	biological_process
# 1	GO:0034504	protein localization to nucleus	biological_process
# 1	GO:0007380	specification of segmental identity, head	biological_process
# 1	GO:0010033	response to organic substance	biological_process
# 1	GO:0010154	fruit development	biological_process
# 1	GO:0010077	maintenance of inflorescence meristem identity	biological_process
# 1	GO:0010076	maintenance of floral meristem identity	biological_process
# 1	GO:0009640	photomorphogenesis	biological_process
# 1	GO:0007422	peripheral nervous system development	biological_process
# 1	GO:0046983	protein dimerization activity	molecular_function
# 1	GO:0007420	brain development	biological_process
# 1	GO:0009965	leaf morphogenesis	biological_process
# 1	GO:0045931	positive regulation of mitotic cell cycle	biological_process
# 1	GO:0003785	actin monomer binding	molecular_function
# 1	GO:0051015	actin filament binding	molecular_function
# 1	GO:0010229	inflorescence development	biological_process
# 1	GO:0010227	floral organ abscission	biological_process
# 1	GO:0010223	secondary shoot formation	biological_process
# 1	GO:0008285	negative regulation of cell population proliferation	biological_process
# 1	GO:0007476	imaginal disc-derived wing morphogenesis	biological_process
# 1	GO:0048735	haltere morphogenesis	biological_process
# 1	GO:0090470	shoot organ boundary specification	biological_process
# 1	GO:0045664	regulation of neuron differentiation	biological_process
# 1	GO:0048457	floral whorl morphogenesis	biological_process
# 1	GO:0045944	positive regulation of transcription by RNA polymerase II	biological_process
# 1	GO:0000122	negative regulation of transcription by RNA polymerase II	biological_process
# 1	GO:0009605	response to external stimulus	biological_process
# 1	GO:0072002	Malpighian tubule development	biological_process
# 1	GO:2000497	positive regulation of cell proliferation involved in compound eye morphogenesis	biological_process
# 1	GO:0007480	imaginal disc-derived leg morphogenesis	biological_process
# 1	GO:0010371	regulation of gibberellin biosynthetic process	biological_process
# 1	GO:0045638	negative regulation of myeloid cell differentiation	biological_process
# 1	GO:0010051	xylem and phloem pattern formation	biological_process
# 1	GO:0008134	transcription factor binding	molecular_function
# 1	GO:0080006	internode patterning	biological_process
# 1	GO:0048510	regulation of timing of transition from vegetative to reproductive phase	biological_process
# 1	GO:0010089	xylem development	biological_process
# 1	GO:0043069	negative regulation of programmed cell death	biological_process
# 1	GO:0043168	anion binding	molecular_function
# 1	GO:0006672	ceramide metabolic process	biological_process
# 1	GO:0005509	calcium ion binding	molecular_function
# 1	GO:0001729	ceramide kinase activity	molecular_function
# 1	GO:0016773	phosphotransferase activity, alcohol group as acceptor	molecular_function
# 1	GO:0030148	sphingolipid biosynthetic process	biological_process
# 1	GO:0052793	pectin acetylesterase activity	molecular_function
# 1	GO:0003002	regionalization	biological_process
# 1	GO:0009966	regulation of signal transduction	biological_process
# 1	GO:0035220	wing disc development	biological_process
# 1	GO:0048731	system development	biological_process
# 1	GO:0071555	cell wall organization	biological_process
# 1	GO:0004519	endonuclease activity	molecular_function
# 1	GO:0010214	seed coat development	biological_process
# 1	GO:0140547	acquisition of seed longevity	biological_process
# 1	GO:0070979	protein K11-linked ubiquitination	biological_process
# 1	GO:0009793	embryo development ending in seed dormancy	biological_process
# 1	GO:0031145	anaphase-promoting complex-dependent catabolic process	biological_process
# 1	GO:0045842	positive regulation of mitotic metaphase/anaphase transition	biological_process
# 1	GO:0048481	plant ovule development	biological_process
# 1	GO:0016301	kinase activity	molecular_function
# 1	GO:0016787	hydrolase activity	molecular_function
# 1	GO:0009416	response to light stimulus	biological_process
# 1	GO:0042742	defense response to bacterium	biological_process
# 1	GO:0051716	cellular response to stimulus	biological_process
# 1	GO:0008195	phosphatidate phosphatase activity	molecular_function
# 1	GO:0006651	diacylglycerol biosynthetic process	biological_process
# 1	GO:0000822	inositol hexakisphosphate binding	molecular_function
# 1	GO:0003724	RNA helicase activity	molecular_function
# 1	GO:0006409	tRNA export from nucleus	biological_process
# 1	GO:0006415	translational termination	biological_process
# 1	GO:0006417	regulation of translation	biological_process
# 1	GO:0007286	spermatid development	biological_process
# 1	GO:0009408	response to heat	biological_process
# 1	GO:0016973	poly(A)+ mRNA export from nucleus	biological_process
# 1	GO:0000981	DNA-binding transcription factor activity, RNA polymerase II-specific	molecular_function
# 1	GO:0006357	regulation of transcription by RNA polymerase II	biological_process
# 1	GO:0009739	response to gibberellin	biological_process
# 1	GO:0042631	cellular response to water deprivation	biological_process
# 1	GO:0045893	positive regulation of DNA-templated transcription	biological_process
# 1	GO:0071215	cellular response to abscisic acid stimulus	biological_process
# 1	GO:0071472	cellular response to salt stress	biological_process
# 1	GO:2000214	regulation of proline metabolic process	biological_process
# 1	GO:2000377	regulation of reactive oxygen species metabolic process	biological_process
# 1	GO:0033862	UMP kinase activity	molecular_function
# 1	GO:0006225	UDP biosynthetic process	biological_process
# 1	GO:0044210	'de novo' CTP biosynthetic process	biological_process
# 1	GO:0046940	nucleoside monophosphate phosphorylation	biological_process
# 1	GO:0016920	pyroglutamyl-peptidase activity	molecular_function
# 1	GO:0006508	proteolysis	biological_process
# 1	GO:0008017	microtubule binding	molecular_function
# 1	GO:0008574	plus-end-directed microtubule motor activity	molecular_function
# 1	GO:0019903	protein phosphatase binding	molecular_function
# 1	GO:0030507	spectrin binding	molecular_function
# 1	GO:0031267	small GTPase binding	molecular_function
# 1	GO:0000281	mitotic cytokinesis	biological_process
# 1	GO:0000911	cytokinesis by cell plate formation	biological_process
# 1	GO:0007112	male meiosis cytokinesis	biological_process
# 1	GO:0051299	centrosome separation	biological_process
# 1	GO:0055046	microgametogenesis	biological_process
# 1	GO:0080175	phragmoplast microtubule organization	biological_process
# 1	GO:0090307	mitotic spindle assembly	biological_process
# 1	GO:1902414	protein localization to cell junction	biological_process
# 1	GO:0015171	amino acid transmembrane transporter activity	molecular_function
# 1	GO:0003333	amino acid transmembrane transport	biological_process
# 1	GO:0009834	plant-type secondary cell wall biogenesis	biological_process
# 1	GO:0010315	auxin export across the plasma membrane	biological_process
# 1	GO:0000302	response to reactive oxygen species	biological_process
# 1	GO:0009658	chloroplast organization	biological_process
# 1	GO:0048366	leaf development	biological_process
# 1	GO:0043565	sequence-specific DNA binding	molecular_function
# 1	GO:0005543	phospholipid binding	molecular_function
# 1	GO:0097001	ceramide binding	molecular_function
# 1	GO:0006869	lipid transport	biological_process
# 1	GO:0009958	positive gravitropism	biological_process
# 1	GO:0045892	negative regulation of DNA-templated transcription	biological_process
# 1	GO:0046872	metal ion binding	molecular_function
# 1	GO:0031227	N/A	N/A
# 1	GO:0008380	RNA splicing	biological_process
# 1	GO:1903047	mitotic cell cycle process	biological_process
# 1	GO:0051707	response to other organism	biological_process
# 1	GO:0033043	regulation of organelle organization	biological_process
# 1	GO:0043167	ion binding	molecular_function
# 1	GO:0008289	lipid binding	molecular_function
# 1	GO:0032981	mitochondrial respiratory chain complex I assembly	biological_process
# 1	GO:0032446	protein modification by small protein conjugation	biological_process
# 1	GO:0072702	response to methyl methanesulfonate	biological_process
# 1	GO:2001020	N/A	N/A
# 1	GO:0009788	negative regulation of abscisic acid-activated signaling pathway	biological_process
# 1	GO:0006511	ubiquitin-dependent protein catabolic process	biological_process
# 1	GO:0004842	ubiquitin-protein transferase activity	molecular_function
# 1	GO:0030154	cell differentiation	biological_process
# 1	GO:0010564	regulation of cell cycle process	biological_process
# 1	GO:0047268	galactinol-raffinose galactosyltransferase activity	molecular_function
# 1	GO:0047274	galactinol-sucrose galactosyltransferase activity	molecular_function
# 1	GO:0052692	raffinose alpha-galactosidase activity	molecular_function
# 1	GO:0006979	response to oxidative stress	biological_process
# 1	GO:0034484	raffinose catabolic process	biological_process
# 1	GO:0010182	sugar mediated signaling pathway	biological_process
# 1	GO:0016554	cytidine to uridine editing	biological_process
# count	GO ID	GO Term	namespace
# 10	GO:0005515	protein binding	molecular_function
# 3	GO:0000166	nucleotide binding	molecular_function
# 3	GO:0003729	mRNA binding	molecular_function
# 2	GO:0000978	RNA polymerase II cis-regulatory region sequence-specific DNA binding	molecular_function
# 2	GO:0008270	zinc ion binding	molecular_function
# 2	GO:0005524	ATP binding	molecular_function
# 2	GO:0016887	ATP hydrolysis activity	molecular_function
# 1	GO:0008092	cytoskeletal protein binding	molecular_function
# 1	GO:0000254	C-4 methylsterol oxidase activity	molecular_function
# 1	GO:0005506	iron ion binding	molecular_function
# 1	GO:0009924	octadecanal decarbonylase activity	molecular_function
# 1	GO:1990465	aldehyde oxygenase (deformylating) activity	molecular_function
# 1	GO:0003713	transcription coactivator activity	molecular_function
# 1	GO:0031490	chromatin DNA binding	molecular_function
# 1	GO:0001228	DNA-binding transcription activator activity, RNA polymerase II-specific	molecular_function
# 1	GO:0046983	protein dimerization activity	molecular_function
# 1	GO:0003785	actin monomer binding	molecular_function
# 1	GO:0051015	actin filament binding	molecular_function
# 1	GO:0008134	transcription factor binding	molecular_function
# 1	GO:0043168	anion binding	molecular_function
# 1	GO:0005509	calcium ion binding	molecular_function
# 1	GO:0001729	ceramide kinase activity	molecular_function
# 1	GO:0016773	phosphotransferase activity, alcohol group as acceptor	molecular_function
# 1	GO:0052793	pectin acetylesterase activity	molecular_function
# 1	GO:0004519	endonuclease activity	molecular_function
# 1	GO:0016301	kinase activity	molecular_function
# 1	GO:0016787	hydrolase activity	molecular_function
# 1	GO:0008195	phosphatidate phosphatase activity	molecular_function
# 1	GO:0000822	inositol hexakisphosphate binding	molecular_function
# 1	GO:0003724	RNA helicase activity	molecular_function
# 1	GO:0000981	DNA-binding transcription factor activity, RNA polymerase II-specific	molecular_function
# 1	GO:0033862	UMP kinase activity	molecular_function
# 1	GO:0016920	pyroglutamyl-peptidase activity	molecular_function
# 1	GO:0008017	microtubule binding	molecular_function
# 1	GO:0008574	plus-end-directed microtubule motor activity	molecular_function
# 1	GO:0019903	protein phosphatase binding	molecular_function
# 1	GO:0030507	spectrin binding	molecular_function
# 1	GO:0031267	small GTPase binding	molecular_function
# 1	GO:0015171	amino acid transmembrane transporter activity	molecular_function
# 1	GO:0043565	sequence-specific DNA binding	molecular_function
# 1	GO:0005543	phospholipid binding	molecular_function
# 1	GO:0097001	ceramide binding	molecular_function
# 1	GO:0046872	metal ion binding	molecular_function
# 1	GO:0031227	N/A	N/A
# 1	GO:0043167	ion binding	molecular_function
# 1	GO:0008289	lipid binding	molecular_function
# 1	GO:2001020	N/A	N/A
# 1	GO:0004842	ubiquitin-protein transferase activity	molecular_function
# 1	GO:0047268	galactinol-raffinose galactosyltransferase activity	molecular_function
# 1	GO:0047274	galactinol-sucrose galactosyltransferase activity	molecular_function
# 1	GO:0052692	raffinose alpha-galactosidase activity	molecular_function
# count	GO ID	GO Term	namespace
# 6	GO:0016021	membrane	cellular_component
# 4	GO:0005739	mitochondrion	cellular_component
# 3	GO:0005829	cytosol	cellular_component
# 3	GO:0009507	chloroplast	cellular_component
# 2	GO:0005634	nucleus	cellular_component
# 2	GO:0005929	cilium	cellular_component
# 2	GO:0016020	membrane	cellular_component
# 2	GO:0012505	endomembrane system	cellular_component
# 2	GO:0005737	cytoplasm	cellular_component
# 2	GO:0005886	plasma membrane	cellular_component
# 2	GO:0005794	Golgi apparatus	cellular_component
# 1	GO:0005871	kinesin complex	cellular_component
# 1	GO:0030424	axon	cellular_component
# 1	GO:0031982	vesicle	cellular_component
# 1	GO:0055028	cortical microtubule	cellular_component
# 1	GO:0005789	endoplasmic reticulum membrane	cellular_component
# 1	GO:0071944	cell periphery	cellular_component
# 1	GO:0016592	mediator complex	cellular_component
# 1	GO:0015630	microtubule cytoskeleton	cellular_component
# 1	GO:0090575	RNA polymerase II transcription regulator complex	cellular_component
# 1	GO:0045171	intercellular bridge	cellular_component
# 1	GO:0015629	actin cytoskeleton	cellular_component
# 1	GO:0000785	chromatin	cellular_component
# 1	GO:0005654	nucleoplasm	cellular_component
# 1	GO:0005773	vacuole	cellular_component
# 1	GO:0098588	bounding membrane of organelle	cellular_component
# 1	GO:0005576	extracellular region	cellular_component
# 1	GO:0005680	anaphase-promoting complex	cellular_component
# 1	GO:0034399	nuclear periphery	cellular_component
# 1	GO:0070013	intracellular organelle lumen	cellular_component
# 1	GO:0031090	organelle membrane	cellular_component
# 1	GO:0005844	polysome	cellular_component
# 1	GO:0005934	cellular bud tip	cellular_component
# 1	GO:0010494	cytoplasmic stress granule	cellular_component
# 1	GO:0033391	chromatoid body	cellular_component
# 1	GO:0044614	nuclear pore cytoplasmic filaments	cellular_component
# 1	GO:0000922	spindle pole	cellular_component
# 1	GO:0005641	nuclear envelope lumen	cellular_component
# 1	GO:0005813	centrosome	cellular_component
# 1	GO:0005814	centriole	cellular_component
# 1	GO:0005876	spindle microtubule	cellular_component
# 1	GO:0009524	phragmoplast	cellular_component
# 1	GO:0016939	kinesin II complex	cellular_component
# 1	GO:0032153	cell division site	cellular_component
# 1	GO:0031969	chloroplast membrane	cellular_component
# 1	GO:0031965	nuclear membrane	cellular_component
# 1	GO:0044232	organelle membrane contact site	cellular_component
# 1	GO:0031227	N/A	N/A
# 1	GO:0005694	chromosome	cellular_component
# 1	GO:0031410	cytoplasmic vesicle	cellular_component
# 1	GO:2001020	N/A	N/A
# 1	GO:0005856	cytoskeleton	cellular_component
# 1	GO:0031981	nuclear lumen	cellular_component

# %% [markdown]
# # GO Enrichment Analysis

# %% [markdown]
# ### `GOEnrichmentStudy` object in `goatools`, key arguments:
#
# 1. **`pop`**:
#    - The population parameter represents all possible items that could be sampled. In the context of GO enrichment, it's typically the list of all gene IDs from your background set.
#
# 2. **`assoc`**:
#    - The association between your items (genes) and the groups (GO terms). This is a dictionary where keys are gene IDs and values are sets of GO IDs.
#
# 3. **`obo_dag`**:
#    - An object representing the GO terms and their hierarchical relationships, usually obtained by parsing the GO OBO file with `obo_parser.GODag()`.
#
# 4. **`propagate_counts`** (optional, default `True`):
#    - If `True`, the gene counts will be propagated up the GO DAG, so that each term includes counts for all descendant terms.
#
# 5. **`alpha`** (optional, default `0.05`):
#    - The significance level for the statistical tests.
#
# 6. **`methods`** (optional):
#    - The methods for multiple test correction, such as `['fdr_bh']` for Benjamini-Hochberg.
#
# 7. **`pvalcalc`** (optional):
#    - The object for calculating p-values. By default, `goatools` uses Fisher's exact test.
#
# 8. **`min_overlap`** (optional, default `0.7`):
#    - The minimum overlap between the study group and the GO term.
#
# 9. **`prunetree`** (optional, default `True`):
#    - If `True`, GO terms without any associated genes in the population will be pruned from the analysis.
#
# 10. **`go2geneids`** (optional):
#     - A dictionary mapping GO IDs to gene IDs. This can be used instead of `assoc` to provide associations.
#
# 11. **`geneid2symbol`** (optional):
#     - A dictionary mapping gene IDs to gene symbols, which can be useful for labeling output.
#
# 12. **`evidence_set`** (optional):
#     - A set of evidence codes to use. If not specified, all evidence codes will be included.
#
# 13. **`relationships`** (optional):
#     - A set of extra relationship types to include when building the GO DAG, such as `'part_of'` or `'regulates'`.
#
# 14. **`keep_if_no_id`** (optional, default `False`):
#     - If `True`, genes without GO IDs in the `assoc` will be kept in the population.
#
# 15. **`study`**:
#     - A list of items (genes) for which you want to check enrichment. This is typically the list of genes corresponding to your non-zero features.
#
#
# The `GOEnrichmentStudy` class in the `goatools` library key attributes:
#
# 1. **`goterm`**:
#    - This attribute is an object representing the GO term itself. It contains further details about the term, like its name, namespace, and description.
#
# 2. **`p_uncorrected`**:
#    - The raw, uncorrected p-value resulting from the enrichment test (e.g., Fisher's exact test).
#
# 3. **`p_fdr_bh`**:
#    - The p-value adjusted for multiple testing using the Benjamini-Hochberg false discovery rate method.
#
# 4. **`enrichment`**:
#    - This indicates whether the GO term is overrepresented (`'e'` for enriched) or underrepresented (`'p'` for purified) in the study set compared to the background.
#
# 5. **`ratio_in_study`**:
#    - A tuple showing the number of genes in the study set that are annotated with this GO term and the total number of genes in the study set.
#
# 6. **`ratio_in_pop`**:
#    - A tuple showing the number of genes in the background population that are annotated with this GO term and the total number of genes in the background population.
#
# 7. **`study_items`**:
#    - A list of genes from your study set that are annotated with this GO term.
#
# 8. **`study_count`**:
#    - The number of genes in your study set that are annotated with this GO term.
#
# 9. **`pop_count`**:
#    - The number of genes in the background population that are annotated with this GO term.
#
# 10. **`study_n`**:
#     - The total number of genes in your study set.
#
# 11. **`pop_n`**:
#     - The total number of genes in the background population.
#
# 12. **`name`** (if available):
#     - The name of the GO term.
#
# 13. **`namespace`** (if available):
#     - The namespace/category of the GO term, such as biological_process, Molecular Function, or Cellular Component.
#
# 14. **`depth`** (if available):
#     - The depth of the GO term in the GO hierarchy.
#
# 15. **`is_obsolete`** (if available):
#     - Indicates whether the GO term is obsolete.
#
# Remember, the availability of some of these attributes might depend on the specifics of how `GOEnrichmentStudy` is set up and run, and the version of `goatools` you are using. These attributes provide a comprehensive view of each GO term's enrichment analysis results, allowing for detailed interpretation and further analysis.
#
# https://github.com/tanghaibao/goatools/blob/main/notebooks/goea_nbt3102.ipynb

# %%
glucose_goea_sig = [r for r in glucose_goea if r.p_fdr_bh < 0.05]
citricAcid_goea_sig = [r for r in citricAcid_goea if r.p_fdr_bh < 0.05]
sucrose_goea_sig = [r for r in sucrose_goea if r.p_fdr_bh < 0.05]
print(f"{len(glucose_goea_sig), len(citricAcid_goea_sig), len(sucrose_goea_sig)}")
# Out:
# (236, 190, 70)
